# %% [markdown]
# # Object Relational Mapping: SQLAlchemy
#
# SQLAlchemy provides an Object Relational Mapper (ORM) that allows us to interact with databases using pythonic object-oriented code rather than writing SQL queries. Out of the box it only works with SQLite, which is based on providing the entire database in a single file and only allows access via a single connection at a time. It is thus not recommended to use SQLite for any production web-based applications or any larger projects.
#
# We use the [Chinook](https://github.com/lerocha/chinook-database) database as our example. The Chinook data model represents a digital media store, including tables for artists, albums, media tracks, invoices and customers.
#
# There are so many ways to query a database that we would never be able to go through all of them (also that would be very boring), so there are two cheat sheets that I recommend you keep a record of:
#
# - [SQL cheat sheet from sqltutorial.org](https://www.sqltutorial.org/sql-cheat-sheet/) (see PDF)
# - [sqlalchemy cheat sheet](https://github.com/crazyguitar/pysheeet/blob/master/docs/notes/python-sqlalchemy.rst) (Git repository that you could consider forking)

# %% [markdown]
# |EmployeeId|LastName|FirstName|Title|ReportsTo|BirthDate|HireDate|Address|City|State|Country|PostalCode|Phone|Fax|Email|
# |---|---|---|---|---|---|---|---|---|---|---|---|---|---|---|
# |1|Adams|Andrew|General Manager||1962-02-18 00:00:00|2002-08-14 00:00:00|11120 Jasper Ave NW|Edmonton|AB|Canada|T5K 2N1|+1 (780) 428-9482|+1 (780) 428-3457|andrew@chinookcorp.com|
# |2|Edwards|Nancy|Sales Manager|1|1958-12-08 00:00:00|2002-05-01 00:00:00|825 8 Ave SW|Calgary|AB|Canada|T2P 2T3|+1 (403) 262-3443|+1 (403) 262-3322|nancy@chinookcorp.com|
# |3|Peacock|Jane|Sales Support Agent|2|1973-08-29 00:00:00|2002-04-01 00:00:00|1111 6 Ave SW|Calgary|AB|Canada|T2P 5M5|+1 (403) 262-3443|+1 (403) 262-6712|jane@chinookcorp.com|
# |4|Park|Margaret|Sales Support Agent|2|1947-09-19 00:00:00|2003-05-03 00:00:00|683 10 Street SW|Calgary|AB|Canada|T2P 5G3|+1 (403) 263-4423|+1 (403) 263-4289|margaret@chinookcorp.com|

# %%
import sqlalchemy as db

# %%
engine = db.create_engine('sqlite:///chinook.db')
# for a Postgres DB
# engine = db.create_engine('postgresql+psycopg2://user:pass@localhost/chinook)
connection = engine.connect()
metadata = db.MetaData()

# List tables in database
print(engine.table_names())
# Out:
# ['albums', 'artists', 'customers', 'employees', 'genres', 'invoice_items', 'invoices', 'media_types', 'playlist_track', 'playlists', 'sqlite_sequence', 'sqlite_stat1', 'tracks']

# %%
employees = db.Table('employees', metadata, autoload=True, autoload_with=engine)

# %% [markdown]
# The table 'employees' contains the following columns:

# %%
print(employees.columns.keys())
# Out:
# ['EmployeeId', 'LastName', 'FirstName', 'Title', 'ReportsTo', 'BirthDate', 'HireDate', 'Address', 'City', 'State', 'Country', 'PostalCode', 'Phone', 'Fax', 'Email']

# %% [markdown]
# The full metadata for the table contains additional information on for example the data types contained in the columns.

# %%
print(repr(metadata.tables['employees']))
# Out:
# Table('employees', MetaData(bind=None), Column('EmployeeId', INTEGER(), table=<employees>, primary_key=True, nullable=False), Column('LastName', NVARCHAR(length=20), table=<employees>, nullable=False), Column('FirstName', NVARCHAR(length=20), table=<employees>, nullable=False), Column('Title', NVARCHAR(length=30), table=<employees>), Column('ReportsTo', INTEGER(), ForeignKey('employees.EmployeeId'), table=<employees>), Column('BirthDate', DATETIME(), table=<employees>), Column('HireDate', DATETIME(), table=<employees>), Column('Address', NVARCHAR(length=70), table=<employees>), Column('City', NVARCHAR(length=40), table=<employees>), Column('State', NVARCHAR(length=40), table=<employees>), Column('Country', NVARCHAR(length=40), table=<employees>), Column('PostalCode', NVARCHAR(length=10), table=<employees>), Column('Phone', NVARCHAR(length=24), table=<employees>), Column('Fax', NVARCHAR(length=24), table=<employees>), Column('Email', NVARCHAR(length=60), table=<employees>), schema=None)

# %% [markdown]
# ### Querying the DB
#
# Now let's see what some common SQL queries look like in sqlalchemy:
#
# SQL:
#
# - SELECT * FROM employees

# %%
query = db.select([employees])
ResultProxy = connection.execute(query)
ResultSet = ResultProxy.fetchall()
ResultSet[:3]
# Out:
# [(1, 'Adams', 'Andrew', 'General Manager', None, datetime.datetime(1962, 2, 18, 0, 0), datetime.datetime(2002, 8, 14, 0, 0), '11120 Jasper Ave NW', 'Edmonton', 'AB', 'Canada', 'T5K 2N1', '+1 (780) 428-9482', '+1 (780) 428-3457', 'andrew@chinookcorp.com'),
#  (2, 'Edwards', 'Nancy', 'Sales Manager', 1, datetime.datetime(1958, 12, 8, 0, 0), datetime.datetime(2002, 5, 1, 0, 0), '825 8 Ave SW', 'Calgary', 'AB', 'Canada', 'T2P 2T3', '+1 (403) 262-3443', '+1 (403) 262-3322', 'nancy@chinookcorp.com'),
#  (3, 'Peacock', 'Jane', 'Sales Support Agent', 2, datetime.datetime(1973, 8, 29, 0, 0), datetime.datetime(2002, 4, 1, 0, 0), '1111 6 Ave SW', 'Calgary', 'AB', 'Canada', 'T2P 5M5', '+1 (403) 262-3443', '+1 (403) 262-6712', 'jane@chinookcorp.com')]

# %% [markdown]
# ```ResultProxy``` here is the _object_ returned by the ```execute()``` method. It can be used to extract data in several ways, while ```ResultSet``` contains the actual data we asked for from ```ResultProxy``` (in this case just everything).

# %%
# Use fetchmany to fetch a specific number of entries (useful for large db)
ResultProxy = connection.execute(query)
# fetch first 3 entries
ResultSet = ResultProxy.fetchmany(3)
print(ResultSet)
# fetch next 3 entries
ResultSet = ResultProxy.fetchmany(3)
print(ResultSet)
# Out:
# [(1, 'Adams', 'Andrew', 'General Manager', None, datetime.datetime(1962, 2, 18, 0, 0), datetime.datetime(2002, 8, 14, 0, 0), '11120 Jasper Ave NW', 'Edmonton', 'AB', 'Canada', 'T5K 2N1', '+1 (780) 428-9482', '+1 (780) 428-3457', 'andrew@chinookcorp.com'), (2, 'Edwards', 'Nancy', 'Sales Manager', 1, datetime.datetime(1958, 12, 8, 0, 0), datetime.datetime(2002, 5, 1, 0, 0), '825 8 Ave SW', 'Calgary', 'AB', 'Canada', 'T2P 2T3', '+1 (403) 262-3443', '+1 (403) 262-3322', 'nancy@chinookcorp.com'), (3, 'Peacock', 'Jane', 'Sales Support Agent', 2, datetime.datetime(1973, 8, 29, 0, 0), datetime.datetime(2002, 4, 1, 0, 0), '1111 6 Ave SW', 'Calgary', 'AB', 'Canada', 'T2P 5M5', '+1 (403) 262-3443', '+1 (403) 262-6712', 'jane@chinookcorp.com')]
# [(4, 'Park', 'Margaret', 'Sales Support Agent', 2, datetime.datetime(1947, 9, 19, 0, 0), datetime.datetime(2003, 5, 3, 0, 0), '683 10 Street SW', 'Calgary', 'AB', 'Canada', 'T2P 5G3', '+1 (403) 263-4423', '+1 (403) 263-4289', 'margaret@chinookcorp.com'), (5, 'Johnson', 'Steve', 'Sales Support Agent', 2, datetime.datetime(1965, 3, 3, 0, 0), datetime.datetime(2003, 10, 17, 0, 0), '7727B 41 Ave', 'Calgary', 'AB', 'Canada', 'T3B 1Y7', '1 (780) 836-9987', '1 (780) 836-9543', 'steve@chinookcorp.com'), (6, 'Mitchell', 'Michael', 'IT Manager', 1, datetime.datetime(1973, 7, 1, 0, 0), datetime.datetime(2003, 10, 17, 0, 0), '5827 Bowness Road NW', 'Calgary', 'AB', 'Canada', 'T3B 0C5', '+1 (403) 246-9887', '+1 (403) 246-9899', 'michael@chinookcorp.com')]

# %% [markdown]
# It is also possible to supply verbatim SQL queries as Strings:

# %%
query = 'SELECT * FROM employees'
ResultProxy = connection.execute(query)
ResultSet = ResultProxy.fetchmany(3)
ResultSet
# Out:
# [(1, 'Adams', 'Andrew', 'General Manager', None, '1962-02-18 00:00:00', '2002-08-14 00:00:00', '11120 Jasper Ave NW', 'Edmonton', 'AB', 'Canada', 'T5K 2N1', '+1 (780) 428-9482', '+1 (780) 428-3457', 'andrew@chinookcorp.com'),
#  (2, 'Edwards', 'Nancy', 'Sales Manager', 1, '1958-12-08 00:00:00', '2002-05-01 00:00:00', '825 8 Ave SW', 'Calgary', 'AB', 'Canada', 'T2P 2T3', '+1 (403) 262-3443', '+1 (403) 262-3322', 'nancy@chinookcorp.com'),
#  (3, 'Peacock', 'Jane', 'Sales Support Agent', 2, '1973-08-29 00:00:00', '2002-04-01 00:00:00', '1111 6 Ave SW', 'Calgary', 'AB', 'Canada', 'T2P 5M5', '+1 (403) 262-3443', '+1 (403) 262-6712', 'jane@chinookcorp.com')]

# %% [markdown]
# We can also directly create a dataframe by querying using ```pandas```

# %%
df = pd.read_sql_query('SELECT * FROM employees', engine)
df
# Out:
#    EmployeeId  LastName FirstName                Title  ReportsTo  \
# 0           1     Adams    Andrew      General Manager        NaN
# 1           2   Edwards     Nancy        Sales Manager        1.0
# 2           3   Peacock      Jane  Sales Support Agent        2.0
# 3           4      Park  Margaret  Sales Support Agent        2.0
# 4           5   Johnson     Steve  Sales Support Agent        2.0
# 5           6  Mitchell   Michael           IT Manager        1.0
# 6           7      King    Robert             IT Staff        6.0
# 7           8  Callahan     Laura             IT Staff        6.0
#
#              BirthDate             HireDate                      Address  \
# 0  1962-02-18 00:00:00  2002-08-14 00:00:00          11120 Jasper Ave NW
# 1  1958-12-08 00:00:00  2002-05-01 00:00:00                 825 8 Ave SW
# 2  1973-08-29 00:00:00  2002-04-01 00:00:00                1111 6 Ave SW
# 3  1947-09-19 00:00:00  2003-05-03 00:00:00             683 10 Street SW
# 4  1965-03-03 00:00:00  2003-10-17 00:00:00                 7727B 41 Ave
# 5  1973-07-01 00:00:00  2003-10-17 00:00:00         5827 Bowness Road NW
# 6  1970-05-29 00:00:00  2004-01-02 00:00:00  590 Columbia Boulevard West
# 7  1968-01-09 00:00:00  2004-03-04 00:00:00                  923 7 ST NW
#
#          City State Country PostalCode              Phone                Fax  \
# 0    Edmonton    AB  Canada    T5K 2N1  +1 (780) 428-9482  +1 (780) 428-3457
# 1     Calgary    AB  Canada    T2P 2T3  +1 (403) 262-3443  +1 (403) 262-3322
# 2     Calgary    AB  Canada    T2P 5M5  +1 (403) 262-3443  +1 (403) 262-6712
# 3     Calgary    AB  Canada    T2P 5G3  +1 (403) 263-4423  +1 (403) 263-4289
# 4     Calgary    AB  Canada    T3B 1Y7   1 (780) 836-9987   1 (780) 836-9543
# 5     Calgary    AB  Canada    T3B 0C5  +1 (403) 246-9887  +1 (403) 246-9899
# 6  Lethbridge    AB  Canada    T1K 5N8  +1 (403) 456-9986  +1 (403) 456-8485
# 7  Lethbridge    AB  Canada    T1H 1Y8  +1 (403) 467-3351  +1 (403) 467-8772
#
#                       Email
# 0    andrew@chinookcorp.com
# 1     nancy@chinookcorp.com
# 2      jane@chinookcorp.com
# 3  margaret@chinookcorp.com
# 4     steve@chinookcorp.com
# 5   michael@chinookcorp.com
# 6    robert@chinookcorp.com
# 7     laura@chinookcorp.com

# %% [markdown]
# ### Converting to pandas Dataframe
#
# For those familiar with the ```pandas``` package, a table can easily be turned into a Dataframe:

# %%
import pandas as pd
ResultSet = ResultProxy.fetchall()
df = pd.DataFrame(ResultSet)
df.columns = ResultSet[0].keys()
print(df)
# Out:
#    EmployeeId  LastName FirstName     Title  ReportsTo  BirthDate   HireDate  \
# 0           7      King    Robert  IT Staff          6 1970-05-29 2004-01-02
# 1           8  Callahan     Laura  IT Staff          6 1968-01-09 2004-03-04
#
#                        Address        City State Country PostalCode  \
# 0  590 Columbia Boulevard West  Lethbridge    AB  Canada    T1K 5N8
# 1                  923 7 ST NW  Lethbridge    AB  Canada    T1H 1Y8
#
#                Phone                Fax                   Email
# 0  +1 (403) 456-9986  +1 (403) 456-8485  robert@chinookcorp.com
# 1  +1 (403) 467-3351  +1 (403) 467-8772   laura@chinookcorp.com

# %% [markdown]
# ### Filtering
#
# To find all cities in the database:
#
# SQL:
#
# - SELECT City FROM employees

# %%
query = db.select([employees.columns.City])
ResultProxy = connection.execute(query)
ResultSet = ResultProxy.fetchall()
ResultSet
# Out:
# [('Edmonton',),
#  ('Calgary',),
#  ('Calgary',),
#  ('Calgary',),
#  ('Calgary',),
#  ('Calgary',),
#  ('Lethbridge',),
#  ('Lethbridge',)]

# %% [markdown]
# SQL:
#
# - SELECT FirstName, LastName FROM employees WHERE City = 'Lethbridge';

# %%
query = db.select([employees.columns.FirstName, employees.columns.LastName]).where(employees.columns.City == 'Lethbridge')
ResultProxy = connection.execute(query)
ResultSet = ResultProxy.fetchall()
ResultSet
# Out:
# [('Robert', 'King'), ('Laura', 'Callahan')]

# %% [markdown]
# SQL:
#
# - SELECT Title, ReportsTo FROM employees WHERE Title IN ('Sales Manager', 'IT Staff');

# %%
query = db.select([employees.columns.Title, employees.columns.ReportsTo]).where(employees.columns.Title.in_(['Sales Manager', 'IT Staff']))
ResultProxy = connection.execute(query)
ResultSet = ResultProxy.fetchall()
ResultSet
# Out:
# [('Sales Manager', 1), ('IT Staff', 6), ('IT Staff', 6)]

# %% [markdown]
# SQL:
#
# - SELECT * FROM employees WHERE City = 'Calgary' AND NOT Title = 'IT Manager'

# %%
query = db.select([employees]).where(db.and_(employees.columns.City == 'Calgary', employees.columns.Title != 'IT Manager'))
ResultProxy = connection.execute(query)
ResultSet = ResultProxy.fetchall()
ResultSet

# %% [markdown]
# ### Ordering
#
# SQL:
#
# - SELECT * FROM employees ORDER BY HireDate, LastName

# %%
query = db.select([employees]).order_by(db.asc(employees.columns.HireDate), employees.columns.LastName)
ResultProxy = connection.execute(query)
ResultSet = ResultProxy.fetchall()
ResultSet
# Out:
# [(3, 'Peacock', 'Jane', 'Sales Support Agent', 2, datetime.datetime(1973, 8, 29, 0, 0), datetime.datetime(2002, 4, 1, 0, 0), '1111 6 Ave SW', 'Calgary', 'AB', 'Canada', 'T2P 5M5', '+1 (403) 262-3443', '+1 (403) 262-6712', 'jane@chinookcorp.com'),
#  (2, 'Edwards', 'Nancy', 'Sales Manager', 1, datetime.datetime(1958, 12, 8, 0, 0), datetime.datetime(2002, 5, 1, 0, 0), '825 8 Ave SW', 'Calgary', 'AB', 'Canada', 'T2P 2T3', '+1 (403) 262-3443', '+1 (403) 262-3322', 'nancy@chinookcorp.com'),
#  (1, 'Adams', 'Andrew', 'General Manager', None, datetime.datetime(1962, 2, 18, 0, 0), datetime.datetime(2002, 8, 14, 0, 0), '11120 Jasper Ave NW', 'Edmonton', 'AB', 'Canada', 'T5K 2N1', '+1 (780) 428-9482', '+1 (780) 428-3457', 'andrew@chinookcorp.com'),
#  (4, 'Park', 'Margaret', 'Sales Support Agent', 2, datetime.datetime(1947, 9, 19, 0, 0), datetime.datetime(2003, 5, 3, 0, 0), '683 10 Street SW', 'Calgary', 'AB', 'Canada', 'T2P 5G3', '+1 (403) 263-4423', '+1 (403) 263-4289', 'margaret@chinookcorp.com'),
#  (5, 'Johnson', 'Steve', 'Sales Support Agent', 2, datetime.datetime(1965, 3, 3, 0, 0), datetime.datetime(2003, 10, 17, 0, 0), '7727B 41 Ave', 'Calgary', 'AB', 'Canada', 'T3B 1Y7', '1 (780) 836-9987', '1 (780) 836-9543', 'steve@chinookcorp.com'),
#  (6, 'Mitchell', 'Michael', 'IT Manager', 1, datetime.datetime(1973, 7, 1, 0, 0), datetime.datetime(2003, 10, 17, 0, 0), '5827 Bowness Road NW', 'Calgary', 'AB', 'Canada', 'T3B 0C5', '+1 (403) 246-9887', '+1 (403) 246-9899', 'michael@chinookcorp.com'),
#  (7, 'King', 'Robert', 'IT Staff', 6, datetime.datetime(1970, 5, 29, 0, 0), datetime.datetime(2004, 1, 2, 0, 0), '590 Columbia Boulevard West', 'Lethbridge', 'AB', 'Canada', 'T1K 5N8', '+1 (403) 456-9986', '+1 (403) 456-8485', 'robert@chinookcorp.com'),
#  (8, 'Callahan', 'Laura', 'IT Staff', 6, datetime.datetime(1968, 1, 9, 0, 0), datetime.datetime(2004, 3, 4, 0, 0), '923 7 ST NW', 'Lethbridge', 'AB', 'Canada', 'T1H 1Y8', '+1 (403) 467-3351', '+1 (403) 467-8772', 'laura@chinookcorp.com')]

# %% [markdown]
# Let's have a look at another table for the next set of examples:

# %%
invoices = db.Table('invoices', metadata, autoload=True, autoload_with=engine)
print(invoices.columns.keys())
# Out:
# ['InvoiceId', 'CustomerId', 'InvoiceDate', 'BillingAddress', 'BillingCity', 'BillingState', 'BillingCountry', 'BillingPostalCode', 'Total']

# %% [markdown]
# ### Functions
#
# SQL:
#
# - SELECT SUM(Total) FROM invoices

# %%
query = db.select([db.func.sum(invoices.columns.Total)])
ResultProxy = connection.execute(query)
ResultSet = ResultProxy.fetchall()
ResultSet
# Out:
# /home/alexandra/anaconda3/envs/sintef-python-course-db/lib/python3.8/site-packages/sqlalchemy/sql/sqltypes.py:659: SAWarning: Dialect sqlite+pysqlite does *not* support Decimal objects natively, and SQLAlchemy must convert from floating point - rounding errors and other issues may occur. Please consider storing Decimal numbers as strings or integers on this platform for lossless storage.
#   util.warn(
# [(Decimal('2328.60'),)]

# %% [markdown]
# ### Group by
#
# SQL:
#
# - SELECT SUM(Total) as Total, BillingCity FROM invoices

# %%
query = db.select([db.func.sum(invoices.columns.Total).label('Total'), invoices.columns.BillingState]).group_by(invoices.columns.BillingState)
ResultProxy = connection.execute(query)
ResultSet = ResultProxy.fetchall()
ResultSet
# Out:
# [(Decimal('1150.00'), None),
#  (Decimal('37.62'), 'AB'),
#  (Decimal('37.62'), 'AZ'),
#  (Decimal('38.62'), 'BC'),
#  (Decimal('115.86'), 'CA'),
#  (Decimal('37.62'), 'DF'),
#  (Decimal('45.62'), 'Dublin'),
#  (Decimal('39.62'), 'FL'),
#  (Decimal('43.62'), 'IL'),
#  (Decimal('37.62'), 'MA'),
#  (Decimal('37.62'), 'MB'),
#  (Decimal('37.62'), 'NS'),
#  (Decimal('37.62'), 'NSW'),
#  (Decimal('37.62'), 'NT'),
#  (Decimal('37.62'), 'NV'),
#  (Decimal('37.62'), 'NY'),
#  (Decimal('75.24'), 'ON'),
#  (Decimal('39.62'), 'QC'),
#  (Decimal('37.62'), 'RJ'),
#  (Decimal('37.62'), 'RM'),
#  (Decimal('114.86'), 'SP'),
#  (Decimal('47.62'), 'TX'),
#  (Decimal('43.62'), 'UT'),
#  (Decimal('40.62'), 'VV'),
#  (Decimal('39.62'), 'WA'),
#  (Decimal('42.62'), 'WI')]

# %% [markdown]
# ### Exercise: Querying a database using sqlalchemy
#
# Answer the following questions by querying the Chinook database using sqlalchemy.
#
# 1. Provide a query showing Customers (just their full names, customer ID and country) who are not in the US.
# 2. Provide a query only showing the Customers from Brazil.
# 3. Provide a query showing the Invoices of customers who are from Brazil. The resultant table should show the customer's full name, Invoice ID, Date of the invoice and billing country.
# 4. Provide a query showing only the Employees who are Sales Agents.
# 5. Provide a query showing a unique list of billing countries from the Invoice table.
# 6. Provide a query showing the invoices of customers who are from Brazil.
# 7. Provide a query that shows the invoices associated with each sales agent. The resultant table should include the Sales Agent's full name.
# 8. Provide a query that shows the Invoice Total, Customer name, Country and Sale Agent name for all invoices and customers.
# 9. How many Invoices were there in 2009 and 2011? What are the respective total sales for each of those years?
# 10. Looking at the InvoiceLine table, provide a query that COUNTs the number of line items for Invoice ID 37.
# 11. Looking at the InvoiceLine table, provide a query that COUNTs the number of line items for each Invoice. HINT: GROUP BY
# 12. Provide a query that includes the track name with each invoice line item.
# 13. Provide a query that includes the purchased track name AND artist name with each invoice line item.
# 14. Provide a query that shows the # of invoices per country. HINT: GROUP BY
# 15. Provide a query that shows the total number of tracks in each playlist. The Playlist name should be include on the resultant table.
# 16. Provide a query that shows all the Tracks, but displays no IDs. The resultant table should include the Album name, Media type and Genre.
# 17. Provide a query that shows all Invoices but includes the # of invoice line items.
# 18. Provide a query that shows total sales made by each sales agent.
# 19. Which sales agent made the most in sales in 2009?
# 20. Which sales agent made the most in sales in 2010?
# 21. Which sales agent made the most in sales over all?
# 22. Provide a query that shows the # of customers assigned to each sales agent.
# 23. Provide a query that shows the total sales per country. Which country's customers spent the most?
# 24. Provide a query that shows the most purchased track of 2013.
# 25. Provide a query that shows the top 5 most purchased tracks over all.
# 26. Provide a query that shows the top 3 best selling artists.
# 27. Provide a query that shows the most purchased Media Type.

# %%
#1
customers = db.Table('customers', metadata, autoload=True, autoload_with=engine)
query = db.select([customers.columns.FirstName, customers.columns.LastName]).where(customers.columns.Country != 'US')
ResultProxy = connection.execute(query)
ResultSet = ResultProxy.fetchall()

#2
query = db.select([customers]).where(customers.columns.Country == 'Brazil')
ResultProxy = connection.execute(query)
ResultSet = ResultProxy.fetchall()

#3 
invoices = db.Table('invoices', metadata, autoload=True, autoload_with=engine)
query = db.select([invoices, customers]).where(customers.columns.Country == 'Brazil' and customers.columns.customerid == invoices.columns.customerid)
ResultProxy = connection.execute(query)
ResultSet = ResultProxy.fetchall()
ResultSet
# Out:
# [(1, 2, datetime.datetime(2009, 1, 1, 0, 0), 'Theodor-Heuss-Straße 34', 'Stuttgart', None, 'Germany', '70174', Decimal('1.98'), 11, 'Alexandre', 'Rocha', 'Banco do Brasil S.A.', 'Av. Paulista, 2022', 'São Paulo', 'SP', 'Brazil', '01310-200', '+55 (11) 3055-3278', '+55 (11) 3055-8131', 'alero@uol.com.br', 5),
#  (1, 2, datetime.datetime(2009, 1, 1, 0, 0), 'Theodor-Heuss-Straße 34', 'Stuttgart', None, 'Germany', '70174', Decimal('1.98'), 10, 'Eduardo', 'Martins', 'Woodstock Discos', 'Rua Dr. Falcão Filho, 155', 'São Paulo', 'SP', 'Brazil', '01007-010', '+55 (11) 3033-5446', '+55 (11) 3033-4564', 'eduardo@woodstock.com.br', 4),
#  (1, 2, datetime.datetime(2009, 1, 1, 0, 0), 'Theodor-Heuss-Straße 34', 'Stuttgart', None, 'Germany', '70174', Decimal('1.98'), 13, 'Fernanda', 'Ramos', None, 'Qe 7 Bloco G', 'Brasília', 'DF', 'Brazil', '71020-677', '+55 (61) 3363-5547', '+55 (61) 3363-7855', 'fernadaramos4@uol.com.br', 4),
#  (1, 2, datetime.datetime(2009, 1, 1, 0, 0), 'Theodor-Heuss-Straße 34', 'Stuttgart', None, 'Germany', '70174', Decimal('1.98'), 1, 'Luís', 'Gonçalves', 'Embraer - Empresa Brasileira de Aeronáutica S.A.', 'Av. Brigadeiro Faria Lima, 2170', 'São José dos Campos', 'SP', 'Brazil', '12227-000', '+55 (12) 3923-5555', '+55 (12) 3923-5566', 'luisg@embraer.com.br', 3),
#  (1, 2, datetime.datetime(2009, 1, 1, 0, 0), 'Theodor-Heuss-Straße 34', 'Stuttgart', None, 'Germany', '70174', Decimal('1.98'), 12, 'Roberto', 'Almeida', 'Riotur', 'Praça Pio X, 119', 'Rio de Janeiro', 'RJ', 'Brazil', '20040-020', '+55 (21) 2271-7000', '+55 (21) 2271-7070', 'roberto.almeida@riotur.gov.br', 3),
#  (2, 4, datetime.datetime(2009, 1, 2, 0, 0), 'Ullevålsveien 14', 'Oslo', None, 'Norway', '0171', Decimal('3.96'), 11, 'Alexandre', 'Rocha', 'Banco do Brasil S.A.', 'Av. Paulista, 2022', 'São Paulo', 'SP', 'Brazil', '01310-200', '+55 (11) 3055-3278', '+55 (11) 3055-8131', 'alero@uol.com.br', 5),
#  (2, 4, datetime.datetime(2009, 1, 2, 0, 0), 'Ullevålsveien 14', 'Oslo', None, 'Norway', '0171', Decimal('3.96'), 10, 'Eduardo', 'Martins', 'Woodstock Discos', 'Rua Dr. Falcão Filho, 155', 'São Paulo', 'SP', 'Brazil', '01007-010', '+55 (11) 3033-5446', '+55 (11) 3033-4564', 'eduardo@woodstock.com.br', 4),
#  (2, 4, datetime.datetime(2009, 1, 2, 0, 0), 'Ullevålsveien 14', 'Oslo', None, 'Norway', '0171', Decimal('3.96'), 13, 'Fernanda', 'Ramos', None, 'Qe 7 Bloco G', 'Brasília', 'DF', 'Brazil', '71020-677', '+55 (61) 3363-5547', '+55 (61) 3363-7855', 'fernadaramos4@uol.com.br', 4),
#  (2, 4, datetime.datetime(2009, 1, 2, 0, 0), 'Ullevålsveien 14', 'Oslo', None, 'Norway', '0171', Decimal('3.96'), 1, 'Luís', 'Gonçalves', 'Embraer - Empresa Brasileira de Aeronáutica S.A.', 'Av. Brigadeiro Faria Lima, 2170', 'São José dos Campos', 'SP', 'Brazil', '12227-000', '+55 (12) 3923-5555', '+55 (12) 3923-5566', 'luisg@embraer.com.br', 3),
#  (2, 4, datetime.datetime(2009, 1, 2, 0, 0), 'Ullevålsveien 14', 'Oslo', None, 'Norway', '0171', Decimal('3.96'), 12, 'Roberto', 'Almeida', 'Riotur', 'Praça Pio X, 119', 'Rio de Janeiro', 'RJ', 'Brazil', '20040-020', '+55 (21) 2271-7000', '+55 (21) 2271-7070', 'roberto.almeida@riotur.gov.br', 3),
#  (3, 8, datetime.datetime(2009, 1, 3, 0, 0), 'Grétrystraat 63', 'Brussels', None, 'Belgium', '1000', Decimal('5.94'), 11, 'Alexandre', 'Rocha', 'Banco do Brasil S.A.', 'Av. Paulista, 2022', 'São Paulo', 'SP', 'Brazil', '01310-200', '+55 (11) 3055-3278', '+55 (11) 3055-8131', 'alero@uol.com.br', 5),
#  (3, 8, datetime.datetime(2009, 1, 3, 0, 0), 'Grétrystraat 63', 'Brussels', None, 'Belgium', '1000', Decimal('5.94'), 10, 'Eduardo', 'Martins', 'Woodstock Discos', 'Rua Dr. Falcão Filho, 155', 'São Paulo', 'SP', 'Brazil', '01007-010', '+55 (11) 3033-5446', '+55 (11) 3033-4564', 'eduardo@woodstock.com.br', 4),
#  (3, 8, datetime.datetime(2009, 1, 3, 0, 0), 'Grétrystraat 63', 'Brussels', None, 'Belgium', '1000', Decimal('5.94'), 13, 'Fernanda', 'Ramos', None, 'Qe 7 Bloco G', 'Brasília', 'DF', 'Brazil', '71020-677', '+55 (61) 3363-5547', '+55 (61) 3363-7855', 'fernadaramos4@uol.com.br', 4),
#  (3, 8, datetime.datetime(2009, 1, 3, 0, 0), 'Grétrystraat 63', 'Brussels', None, 'Belgium', '1000', Decimal('5.94'), 1, 'Luís', 'Gonçalves', 'Embraer - Empresa Brasileira de Aeronáutica S.A.', 'Av. Brigadeiro Faria Lima, 2170', 'São José dos Campos', 'SP', 'Brazil', '12227-000', '+55 (12) 3923-5555', '+55 (12) 3923-5566', 'luisg@embraer.com.br', 3),
#  (3, 8, datetime.datetime(2009, 1, 3, 0, 0), 'Grétrystraat 63', 'Brussels', None, 'Belgium', '1000', Decimal('5.94'), 12, 'Roberto', 'Almeida', 'Riotur', 'Praça Pio X, 119', 'Rio de Janeiro', 'RJ', 'Brazil', '20040-020', '+55 (21) 2271-7000', '+55 (21) 2271-7070', 'roberto.almeida@riotur.gov.br', 3),
#  (4, 14, datetime.datetime(2009, 1, 6, 0, 0), '8210 111 ST NW', 'Edmonton', 'AB', 'Canada', 'T6G 2C7', Decimal('8.91'), 11, 'Alexandre', 'Rocha', 'Banco do Brasil S.A.', 'Av. Paulista, 2022', 'São Paulo', 'SP', 'Brazil', '01310-200', '+55 (11) 3055-3278', '+55 (11) 3055-8131', 'alero@uol.com.br', 5),
#  (4, 14, datetime.datetime(2009, 1, 6, 0, 0), '8210 111 ST NW', 'Edmonton', 'AB', 'Canada', 'T6G 2C7', Decimal('8.91'), 10, 'Eduardo', 'Martins', 'Woodstock Discos', 'Rua Dr. Falcão Filho, 155', 'São Paulo', 'SP', 'Brazil', '01007-010', '+55 (11) 3033-5446', '+55 (11) 3033-4564', 'eduardo@woodstock.com.br', 4),
#  (4, 14, datetime.datetime(2009, 1, 6, 0, 0), '8210 111 ST NW', 'Edmonton', 'AB', 'Canada', 'T6G 2C7', Decimal('8.91'), 13, 'Fernanda', 'Ramos', None, 'Qe 7 Bloco G', 'Brasília', 'DF', 'Brazil', '71020-677', '+55 (61) 3363-5547', '+55 (61) 3363-7855', 'fernadaramos4@uol.com.br', 4),
#  (4, 14, datetime.datetime(2009, 1, 6, 0, 0), '8210 111 ST NW', 'Edmonton', 'AB', 'Canada', 'T6G 2C7', Decimal('8.91'), 1, 'Luís', 'Gonçalves', 'Embraer - Empresa Brasileira de Aeronáutica S.A.', 'Av. Brigadeiro Faria Lima, 2170', 'São José dos Campos', 'SP', 'Brazil', '12227-000', '+55 (12) 3923-5555', '+55 (12) 3923-5566', 'luisg@embraer.com.br', 3),
#  (4, 14, datetime.datetime(2009, 1, 6, 0, 0), '8210 111 ST NW', 'Edmonton', 'AB', 'Canada', 'T6G 2C7', Decimal('8.91'), 12, 'Roberto', 'Almeida', 'Riotur', 'Praça Pio X, 119', 'Rio de Janeiro', 'RJ', 'Brazil', '20040-020', '+55 (21) 2271-7000', '+55 (21) 2271-7070', 'roberto.almeida@riotur.gov.br', 3),
#  (5, 23, datetime.datetime(2009, 1, 11, 0, 0), '69 Salem Street', 'Boston', 'MA', 'USA', '2113', Decimal('13.86'), 11, 'Alexandre', 'Rocha', 'Banco do Brasil S.A.', 'Av. Paulista, 2022', 'São Paulo', 'SP', 'Brazil', '01310-200', '+55 (11) 3055-3278', '+55 (11) 3055-8131', 'alero@uol.com.br', 5),
#  (5, 23, datetime.datetime(2009, 1, 11, 0, 0), '69 Salem Street', 'Boston', 'MA', 'USA', '2113', Decimal('13.86'), 10, 'Eduardo', 'Martins', 'Woodstock Discos', 'Rua Dr. Falcão Filho, 155', 'São Paulo', 'SP', 'Brazil', '01007-010', '+55 (11) 3033-5446', '+55 (11) 3033-4564', 'eduardo@woodstock.com.br', 4),
#  (5, 23, datetime.datetime(2009, 1, 11, 0, 0), '69 Salem Street', 'Boston', 'MA', 'USA', '2113', Decimal('13.86'), 13, 'Fernanda', 'Ramos', None, 'Qe 7 Bloco G', 'Brasília', 'DF', 'Brazil', '71020-677', '+55 (61) 3363-5547', '+55 (61) 3363-7855', 'fernadaramos4@uol.com.br', 4),
#  (5, 23, datetime.datetime(2009, 1, 11, 0, 0), '69 Salem Street', 'Boston', 'MA', 'USA', '2113', Decimal('13.86'), 1, 'Luís', 'Gonçalves', 'Embraer - Empresa Brasileira de Aeronáutica S.A.', 'Av. Brigadeiro Faria Lima, 2170', 'São José dos Campos', 'SP', 'Brazil', '12227-000', '+55 (12) 3923-5555', '+55 (12) 3923-5566', 'luisg@embraer.com.br', 3),
#  (5, 23, datetime.datetime(2009, 1, 11, 0, 0), '69 Salem Street', 'Boston', 'MA', 'USA', '2113', Decimal('13.86'), 12, 'Roberto', 'Almeida', 'Riotur', 'Praça Pio X, 119', 'Rio de Janeiro', 'RJ', 'Brazil', '20040-020', '+55 (21) 2271-7000', '+55 (21) 2271-7070', 'roberto.almeida@riotur.gov.br', 3),
#  (6, 37, datetime.datetime(2009, 1, 19, 0, 0), 'Berger Straße 10', 'Frankfurt', None, 'Germany', '60316', Decimal('0.99'), 11, 'Alexandre', 'Rocha', 'Banco do Brasil S.A.', 'Av. Paulista, 2022', 'São Paulo', 'SP', 'Brazil', '01310-200', '+55 (11) 3055-3278', '+55 (11) 3055-8131', 'alero@uol.com.br', 5),
#  (6, 37, datetime.datetime(2009, 1, 19, 0, 0), 'Berger Straße 10', 'Frankfurt', None, 'Germany', '60316', Decimal('0.99'), 10, 'Eduardo', 'Martins', 'Woodstock Discos', 'Rua Dr. Falcão Filho, 155', 'São Paulo', 'SP', 'Brazil', '01007-010', '+55 (11) 3033-5446', '+55 (11) 3033-4564', 'eduardo@woodstock.com.br', 4),
#  (6, 37, datetime.datetime(2009, 1, 19, 0, 0), 'Berger Straße 10', 'Frankfurt', None, 'Germany', '60316', Decimal('0.99'), 13, 'Fernanda', 'Ramos', None, 'Qe 7 Bloco G', 'Brasília', 'DF', 'Brazil', '71020-677', '+55 (61) 3363-5547', '+55 (61) 3363-7855', 'fernadaramos4@uol.com.br', 4),
#  (6, 37, datetime.datetime(2009, 1, 19, 0, 0), 'Berger Straße 10', 'Frankfurt', None, 'Germany', '60316', Decimal('0.99'), 1, 'Luís', 'Gonçalves', 'Embraer - Empresa Brasileira de Aeronáutica S.A.', 'Av. Brigadeiro Faria Lima, 2170', 'São José dos Campos', 'SP', 'Brazil', '12227-000', '+55 (12) 3923-5555', '+55 (12) 3923-5566', 'luisg@embraer.com.br', 3),
#  (6, 37, datetime.datetime(2009, 1, 19, 0, 0), 'Berger Straße 10', 'Frankfurt', None, 'Germany', '60316', Decimal('0.99'), 12, 'Roberto', 'Almeida', 'Riotur', 'Praça Pio X, 119', 'Rio de Janeiro', 'RJ', 'Brazil', '20040-020', '+55 (21) 2271-7000', '+55 (21) 2271-7070', 'roberto.almeida@riotur.gov.br', 3),
#  (7, 38, datetime.datetime(2009, 2, 1, 0, 0), 'Barbarossastraße 19', 'Berlin', None, 'Germany', '10779', Decimal('1.98'), 11, 'Alexandre', 'Rocha', 'Banco do Brasil S.A.', 'Av. Paulista, 2022', 'São Paulo', 'SP', 'Brazil', '01310-200', '+55 (11) 3055-3278', '+55 (11) 3055-8131', 'alero@uol.com.br', 5),
#  (7, 38, datetime.datetime(2009, 2, 1, 0, 0), 'Barbarossastraße 19', 'Berlin', None, 'Germany', '10779', Decimal('1.98'), 10, 'Eduardo', 'Martins', 'Woodstock Discos', 'Rua Dr. Falcão Filho, 155', 'São Paulo', 'SP', 'Brazil', '01007-010', '+55 (11) 3033-5446', '+55 (11) 3033-4564', 'eduardo@woodstock.com.br', 4),
#  (7, 38, datetime.datetime(2009, 2, 1, 0, 0), 'Barbarossastraße 19', 'Berlin', None, 'Germany', '10779', Decimal('1.98'), 13, 'Fernanda', 'Ramos', None, 'Qe 7 Bloco G', 'Brasília', 'DF', 'Brazil', '71020-677', '+55 (61) 3363-5547', '+55 (61) 3363-7855', 'fernadaramos4@uol.com.br', 4),
#  (7, 38, datetime.datetime(2009, 2, 1, 0, 0), 'Barbarossastraße 19', 'Berlin', None, 'Germany', '10779', Decimal('1.98'), 1, 'Luís', 'Gonçalves', 'Embraer - Empresa Brasileira de Aeronáutica S.A.', 'Av. Brigadeiro Faria Lima, 2170', 'São José dos Campos', 'SP', 'Brazil', '12227-000', '+55 (12) 3923-5555', '+55 (12) 3923-5566', 'luisg@embraer.com.br', 3),
#  (7, 38, datetime.datetime(2009, 2, 1, 0, 0), 'Barbarossastraße 19', 'Berlin', None, 'Germany', '10779', Decimal('1.98'), 12, 'Roberto', 'Almeida', 'Riotur', 'Praça Pio X, 119', 'Rio de Janeiro', 'RJ', 'Brazil', '20040-020', '+55 (21) 2271-7000', '+55 (21) 2271-7070', 'roberto.almeida@riotur.gov.br', 3),
#  (8, 40, datetime.datetime(2009, 2, 1, 0, 0), '8, Rue Hanovre', 'Paris', None, 'France', '75002', Decimal('1.98'), 11, 'Alexandre', 'Rocha', 'Banco do Brasil S.A.', 'Av. Paulista, 2022', 'São Paulo', 'SP', 'Brazil', '01310-200', '+55 (11) 3055-3278', '+55 (11) 3055-8131', 'alero@uol.com.br', 5),
#  (8, 40, datetime.datetime(2009, 2, 1, 0, 0), '8, Rue Hanovre', 'Paris', None, 'France', '75002', Decimal('1.98'), 10, 'Eduardo', 'Martins', 'Woodstock Discos', 'Rua Dr. Falcão Filho, 155', 'São Paulo', 'SP', 'Brazil', '01007-010', '+55 (11) 3033-5446', '+55 (11) 3033-4564', 'eduardo@woodstock.com.br', 4),
#  (8, 40, datetime.datetime(2009, 2, 1, 0, 0), '8, Rue Hanovre', 'Paris', None, 'France', '75002', Decimal('1.98'), 13, 'Fernanda', 'Ramos', None, 'Qe 7 Bloco G', 'Brasília', 'DF', 'Brazil', '71020-677', '+55 (61) 3363-5547', '+55 (61) 3363-7855', 'fernadaramos4@uol.com.br', 4),
#  (8, 40, datetime.datetime(2009, 2, 1, 0, 0), '8, Rue Hanovre', 'Paris', None, 'France', '75002', Decimal('1.98'), 1, 'Luís', 'Gonçalves', 'Embraer - Empresa Brasileira de Aeronáutica S.A.', 'Av. Brigadeiro Faria Lima, 2170', 'São José dos Campos', 'SP', 'Brazil', '12227-000', '+55 (12) 3923-5555', '+55 (12) 3923-5566', 'luisg@embraer.com.br', 3),
#  (8, 40, datetime.datetime(2009, 2, 1, 0, 0), '8, Rue Hanovre', 'Paris', None, 'France', '75002', Decimal('1.98'), 12, 'Roberto', 'Almeida', 'Riotur', 'Praça Pio X, 119', 'Rio de Janeiro', 'RJ', 'Brazil', '20040-020', '+55 (21) 2271-7000', '+55 (21) 2271-7070', 'roberto.almeida@riotur.gov.br', 3),
#  (9, 42, datetime.datetime(2009, 2, 2, 0, 0), '9, Place Louis Barthou', 'Bordeaux', None, 'France', '33000', Decimal('3.96'), 11, 'Alexandre', 'Rocha', 'Banco do Brasil S.A.', 'Av. Paulista, 2022', 'São Paulo', 'SP', 'Brazil', '01310-200', '+55 (11) 3055-3278', '+55 (11) 3055-8131', 'alero@uol.com.br', 5),
#  (9, 42, datetime.datetime(2009, 2, 2, 0, 0), '9, Place Louis Barthou', 'Bordeaux', None, 'France', '33000', Decimal('3.96'), 10, 'Eduardo', 'Martins', 'Woodstock Discos', 'Rua Dr. Falcão Filho, 155', 'São Paulo', 'SP', 'Brazil', '01007-010', '+55 (11) 3033-5446', '+55 (11) 3033-4564', 'eduardo@woodstock.com.br', 4),
#  (9, 42, datetime.datetime(2009, 2, 2, 0, 0), '9, Place Louis Barthou', 'Bordeaux', None, 'France', '33000', Decimal('3.96'), 13, 'Fernanda', 'Ramos', None, 'Qe 7 Bloco G', 'Brasília', 'DF', 'Brazil', '71020-677', '+55 (61) 3363-5547', '+55 (61) 3363-7855', 'fernadaramos4@uol.com.br', 4),
#  (9, 42, datetime.datetime(2009, 2, 2, 0, 0), '9, Place Louis Barthou', 'Bordeaux', None, 'France', '33000', Decimal('3.96'), 1, 'Luís', 'Gonçalves', 'Embraer - Empresa Brasileira de Aeronáutica S.A.', 'Av. Brigadeiro Faria Lima, 2170', 'São José dos Campos', 'SP', 'Brazil', '12227-000', '+55 (12) 3923-5555', '+55 (12) 3923-5566', 'luisg@embraer.com.br', 3),
#  (9, 42, datetime.datetime(2009, 2, 2, 0, 0), '9, Place Louis Barthou', 'Bordeaux', None, 'France', '33000', Decimal('3.96'), 12, 'Roberto', 'Almeida', 'Riotur', 'Praça Pio X, 119', 'Rio de Janeiro', 'RJ', 'Brazil', '20040-020', '+55 (21) 2271-7000', '+55 (21) 2271-7070', 'roberto.almeida@riotur.gov.br', 3),
#  (10, 46, datetime.datetime(2009, 2, 3, 0, 0), '3 Chatham Street', 'Dublin', 'Dublin', 'Ireland', None, Decimal('5.94'), 11, 'Alexandre', 'Rocha', 'Banco do Brasil S.A.', 'Av. Paulista, 2022', 'São Paulo', 'SP', 'Brazil', '01310-200', '+55 (11) 3055-3278', '+55 (11) 3055-8131', 'alero@uol.com.br', 5),
#  (10, 46, datetime.datetime(2009, 2, 3, 0, 0), '3 Chatham Street', 'Dublin', 'Dublin', 'Ireland', None, Decimal('5.94'), 10, 'Eduardo', 'Martins', 'Woodstock Discos', 'Rua Dr. Falcão Filho, 155', 'São Paulo', 'SP', 'Brazil', '01007-010', '+55 (11) 3033-5446', '+55 (11) 3033-4564', 'eduardo@woodstock.com.br', 4),
#  (10, 46, datetime.datetime(2009, 2, 3, 0, 0), '3 Chatham Street', 'Dublin', 'Dublin', 'Ireland', None, Decimal('5.94'), 13, 'Fernanda', 'Ramos', None, 'Qe 7 Bloco G', 'Brasília', 'DF', 'Brazil', '71020-677', '+55 (61) 3363-5547', '+55 (61) 3363-7855', 'fernadaramos4@uol.com.br', 4),
#  (10, 46, datetime.datetime(2009, 2, 3, 0, 0), '3 Chatham Street', 'Dublin', 'Dublin', 'Ireland', None, Decimal('5.94'), 1, 'Luís', 'Gonçalves', 'Embraer - Empresa Brasileira de Aeronáutica S.A.', 'Av. Brigadeiro Faria Lima, 2170', 'São José dos Campos', 'SP', 'Brazil', '12227-000', '+55 (12) 3923-5555', '+55 (12) 3923-5566', 'luisg@embraer.com.br', 3),
#  (10, 46, datetime.datetime(2009, 2, 3, 0, 0), '3 Chatham Street', 'Dublin', 'Dublin', 'Ireland', None, Decimal('5.94'), 12, 'Roberto', 'Almeida', 'Riotur', 'Praça Pio X, 119', 'Rio de Janeiro', 'RJ', 'Brazil', '20040-020', '+55 (21) 2271-7000', '+55 (21) 2271-7070', 'roberto.almeida@riotur.gov.br', 3),
#  (11, 52, datetime.datetime(2009, 2, 6, 0, 0), '202 Hoxton Street', 'London', None, 'United Kingdom', 'N1 5LH', Decimal('8.91'), 11, 'Alexandre', 'Rocha', 'Banco do Brasil S.A.', 'Av. Paulista, 2022', 'São Paulo', 'SP', 'Brazil', '01310-200', '+55 (11) 3055-3278', '+55 (11) 3055-8131', 'alero@uol.com.br', 5),
#  (11, 52, datetime.datetime(2009, 2, 6, 0, 0), '202 Hoxton Street', 'London', None, 'United Kingdom', 'N1 5LH', Decimal('8.91'), 10, 'Eduardo', 'Martins', 'Woodstock Discos', 'Rua Dr. Falcão Filho, 155', 'São Paulo', 'SP', 'Brazil', '01007-010', '+55 (11) 3033-5446', '+55 (11) 3033-4564', 'eduardo@woodstock.com.br', 4),
#  (11, 52, datetime.datetime(2009, 2, 6, 0, 0), '202 Hoxton Street', 'London', None, 'United Kingdom', 'N1 5LH', Decimal('8.91'), 13, 'Fernanda', 'Ramos', None, 'Qe 7 Bloco G', 'Brasília', 'DF', 'Brazil', '71020-677', '+55 (61) 3363-5547', '+55 (61) 3363-7855', 'fernadaramos4@uol.com.br', 4),
#  (11, 52, datetime.datetime(2009, 2, 6, 0, 0), '202 Hoxton Street', 'London', None, 'United Kingdom', 'N1 5LH', Decimal('8.91'), 1, 'Luís', 'Gonçalves', 'Embraer - Empresa Brasileira de Aeronáutica S.A.', 'Av. Brigadeiro Faria Lima, 2170', 'São José dos Campos', 'SP', 'Brazil', '12227-000', '+55 (12) 3923-5555', '+55 (12) 3923-5566', 'luisg@embraer.com.br', 3),
#  (11, 52, datetime.datetime(2009, 2, 6, 0, 0), '202 Hoxton Street', 'London', None, 'United Kingdom', 'N1 5LH', Decimal('8.91'), 12, 'Roberto', 'Almeida', 'Riotur', 'Praça Pio X, 119', 'Rio de Janeiro', 'RJ', 'Brazil', '20040-020', '+55 (21) 2271-7000', '+55 (21) 2271-7070', 'roberto.almeida@riotur.gov.br', 3),
#  (12, 2, datetime.datetime(2009, 2, 11, 0, 0), 'Theodor-Heuss-Straße 34', 'Stuttgart', None, 'Germany', '70174', Decimal('13.86'), 11, 'Alexandre', 'Rocha', 'Banco do Brasil S.A.', 'Av. Paulista, 2022', 'São Paulo', 'SP', 'Brazil', '01310-200', '+55 (11) 3055-3278', '+55 (11) 3055-8131', 'alero@uol.com.br', 5),
#  (12, 2, datetime.datetime(2009, 2, 11, 0, 0), 'Theodor-Heuss-Straße 34', 'Stuttgart', None, 'Germany', '70174', Decimal('13.86'), 10, 'Eduardo', 'Martins', 'Woodstock Discos', 'Rua Dr. Falcão Filho, 155', 'São Paulo', 'SP', 'Brazil', '01007-010', '+55 (11) 3033-5446', '+55 (11) 3033-4564', 'eduardo@woodstock.com.br', 4),
#  (12, 2, datetime.datetime(2009, 2, 11, 0, 0), 'Theodor-Heuss-Straße 34', 'Stuttgart', None, 'Germany', '70174', Decimal('13.86'), 13, 'Fernanda', 'Ramos', None, 'Qe 7 Bloco G', 'Brasília', 'DF', 'Brazil', '71020-677', '+55 (61) 3363-5547', '+55 (61) 3363-7855', 'fernadaramos4@uol.com.br', 4),
#  (12, 2, datetime.datetime(2009, 2, 11, 0, 0), 'Theodor-Heuss-Straße 34', 'Stuttgart', None, 'Germany', '70174', Decimal('13.86'), 1, 'Luís', 'Gonçalves', 'Embraer - Empresa Brasileira de Aeronáutica S.A.', 'Av. Brigadeiro Faria Lima, 2170', 'São José dos Campos', 'SP', 'Brazil', '12227-000', '+55 (12) 3923-5555', '+55 (12) 3923-5566', 'luisg@embraer.com.br', 3),
#  (12, 2, datetime.datetime(2009, 2, 11, 0, 0), 'Theodor-Heuss-Straße 34', 'Stuttgart', None, 'Germany', '70174', Decimal('13.86'), 12, 'Roberto', 'Almeida', 'Riotur', 'Praça Pio X, 119', 'Rio de Janeiro', 'RJ', 'Brazil', '20040-020', '+55 (21) 2271-7000', '+55 (21) 2271-7070', 'roberto.almeida@riotur.gov.br', 3),
#  (13, 16, datetime.datetime(2009, 2, 19, 0, 0), '1600 Amphitheatre Parkway', 'Mountain View', 'CA', 'USA', '94043-1351', Decimal('0.99'), 11, 'Alexandre', 'Rocha', 'Banco do Brasil S.A.', 'Av. Paulista, 2022', 'São Paulo', 'SP', 'Brazil', '01310-200', '+55 (11) 3055-3278', '+55 (11) 3055-8131', 'alero@uol.com.br', 5),
#  (13, 16, datetime.datetime(2009, 2, 19, 0, 0), '1600 Amphitheatre Parkway', 'Mountain View', 'CA', 'USA', '94043-1351', Decimal('0.99'), 10, 'Eduardo', 'Martins', 'Woodstock Discos', 'Rua Dr. Falcão Filho, 155', 'São Paulo', 'SP', 'Brazil', '01007-010', '+55 (11) 3033-5446', '+55 (11) 3033-4564', 'eduardo@woodstock.com.br', 4),
#  (13, 16, datetime.datetime(2009, 2, 19, 0, 0), '1600 Amphitheatre Parkway', 'Mountain View', 'CA', 'USA', '94043-1351', Decimal('0.99'), 13, 'Fernanda', 'Ramos', None, 'Qe 7 Bloco G', 'Brasília', 'DF', 'Brazil', '71020-677', '+55 (61) 3363-5547', '+55 (61) 3363-7855', 'fernadaramos4@uol.com.br', 4),
#  (13, 16, datetime.datetime(2009, 2, 19, 0, 0), '1600 Amphitheatre Parkway', 'Mountain View', 'CA', 'USA', '94043-1351', Decimal('0.99'), 1, 'Luís', 'Gonçalves', 'Embraer - Empresa Brasileira de Aeronáutica S.A.', 'Av. Brigadeiro Faria Lima, 2170', 'São José dos Campos', 'SP', 'Brazil', '12227-000', '+55 (12) 3923-5555', '+55 (12) 3923-5566', 'luisg@embraer.com.br', 3),
#  (13, 16, datetime.datetime(2009, 2, 19, 0, 0), '1600 Amphitheatre Parkway', 'Mountain View', 'CA', 'USA', '94043-1351', Decimal('0.99'), 12, 'Roberto', 'Almeida', 'Riotur', 'Praça Pio X, 119', 'Rio de Janeiro', 'RJ', 'Brazil', '20040-020', '+55 (21) 2271-7000', '+55 (21) 2271-7070', 'roberto.almeida@riotur.gov.br', 3),
#  (14, 17, datetime.datetime(2009, 3, 4, 0, 0), '1 Microsoft Way', 'Redmond', 'WA', 'USA', '98052-8300', Decimal('1.98'), 11, 'Alexandre', 'Rocha', 'Banco do Brasil S.A.', 'Av. Paulista, 2022', 'São Paulo', 'SP', 'Brazil', '01310-200', '+55 (11) 3055-3278', '+55 (11) 3055-8131', 'alero@uol.com.br', 5),
#  (14, 17, datetime.datetime(2009, 3, 4, 0, 0), '1 Microsoft Way', 'Redmond', 'WA', 'USA', '98052-8300', Decimal('1.98'), 10, 'Eduardo', 'Martins', 'Woodstock Discos', 'Rua Dr. Falcão Filho, 155', 'São Paulo', 'SP', 'Brazil', '01007-010', '+55 (11) 3033-5446', '+55 (11) 3033-4564', 'eduardo@woodstock.com.br', 4),
#  (14, 17, datetime.datetime(2009, 3, 4, 0, 0), '1 Microsoft Way', 'Redmond', 'WA', 'USA', '98052-8300', Decimal('1.98'), 13, 'Fernanda', 'Ramos', None, 'Qe 7 Bloco G', 'Brasília', 'DF', 'Brazil', '71020-677', '+55 (61) 3363-5547', '+55 (61) 3363-7855', 'fernadaramos4@uol.com.br', 4),
#  (14, 17, datetime.datetime(2009, 3, 4, 0, 0), '1 Microsoft Way', 'Redmond', 'WA', 'USA', '98052-8300', Decimal('1.98'), 1, 'Luís', 'Gonçalves', 'Embraer - Empresa Brasileira de Aeronáutica S.A.', 'Av. Brigadeiro Faria Lima, 2170', 'São José dos Campos', 'SP', 'Brazil', '12227-000', '+55 (12) 3923-5555', '+55 (12) 3923-5566', 'luisg@embraer.com.br', 3),
#  (14, 17, datetime.datetime(2009, 3, 4, 0, 0), '1 Microsoft Way', 'Redmond', 'WA', 'USA', '98052-8300', Decimal('1.98'), 12, 'Roberto', 'Almeida', 'Riotur', 'Praça Pio X, 119', 'Rio de Janeiro', 'RJ', 'Brazil', '20040-020', '+55 (21) 2271-7000', '+55 (21) 2271-7070', 'roberto.almeida@riotur.gov.br', 3),
#  (15, 19, datetime.datetime(2009, 3, 4, 0, 0), '1 Infinite Loop', 'Cupertino', 'CA', 'USA', '95014', Decimal('1.98'), 11, 'Alexandre', 'Rocha', 'Banco do Brasil S.A.', 'Av. Paulista, 2022', 'São Paulo', 'SP', 'Brazil', '01310-200', '+55 (11) 3055-3278', '+55 (11) 3055-8131', 'alero@uol.com.br', 5),
#  (15, 19, datetime.datetime(2009, 3, 4, 0, 0), '1 Infinite Loop', 'Cupertino', 'CA', 'USA', '95014', Decimal('1.98'), 10, 'Eduardo', 'Martins', 'Woodstock Discos', 'Rua Dr. Falcão Filho, 155', 'São Paulo', 'SP', 'Brazil', '01007-010', '+55 (11) 3033-5446', '+55 (11) 3033-4564', 'eduardo@woodstock.com.br', 4),
#  (15, 19, datetime.datetime(2009, 3, 4, 0, 0), '1 Infinite Loop', 'Cupertino', 'CA', 'USA', '95014', Decimal('1.98'), 13, 'Fernanda', 'Ramos', None, 'Qe 7 Bloco G', 'Brasília', 'DF', 'Brazil', '71020-677', '+55 (61) 3363-5547', '+55 (61) 3363-7855', 'fernadaramos4@uol.com.br', 4),
#  (15, 19, datetime.datetime(2009, 3, 4, 0, 0), '1 Infinite Loop', 'Cupertino', 'CA', 'USA', '95014', Decimal('1.98'), 1, 'Luís', 'Gonçalves', 'Embraer - Empresa Brasileira de Aeronáutica S.A.', 'Av. Brigadeiro Faria Lima, 2170', 'São José dos Campos', 'SP', 'Brazil', '12227-000', '+55 (12) 3923-5555', '+55 (12) 3923-5566', 'luisg@embraer.com.br', 3),
#  (15, 19, datetime.datetime(2009, 3, 4, 0, 0), '1 Infinite Loop', 'Cupertino', 'CA', 'USA', '95014', Decimal('1.98'), 12, 'Roberto', 'Almeida', 'Riotur', 'Praça Pio X, 119', 'Rio de Janeiro', 'RJ', 'Brazil', '20040-020', '+55 (21) 2271-7000', '+55 (21) 2271-7070', 'roberto.almeida@riotur.gov.br', 3),
#  (16, 21, datetime.datetime(2009, 3, 5, 0, 0), '801 W 4th Street', 'Reno', 'NV', 'USA', '89503', Decimal('3.96'), 11, 'Alexandre', 'Rocha', 'Banco do Brasil S.A.', 'Av. Paulista, 2022', 'São Paulo', 'SP', 'Brazil', '01310-200', '+55 (11) 3055-3278', '+55 (11) 3055-8131', 'alero@uol.com.br', 5),
#  (16, 21, datetime.datetime(2009, 3, 5, 0, 0), '801 W 4th Street', 'Reno', 'NV', 'USA', '89503', Decimal('3.96'), 10, 'Eduardo', 'Martins', 'Woodstock Discos', 'Rua Dr. Falcão Filho, 155', 'São Paulo', 'SP', 'Brazil', '01007-010', '+55 (11) 3033-5446', '+55 (11) 3033-4564', 'eduardo@woodstock.com.br', 4),
#  (16, 21, datetime.datetime(2009, 3, 5, 0, 0), '801 W 4th Street', 'Reno', 'NV', 'USA', '89503', Decimal('3.96'), 13, 'Fernanda', 'Ramos', None, 'Qe 7 Bloco G', 'Brasília', 'DF', 'Brazil', '71020-677', '+55 (61) 3363-5547', '+55 (61) 3363-7855', 'fernadaramos4@uol.com.br', 4),
#  (16, 21, datetime.datetime(2009, 3, 5, 0, 0), '801 W 4th Street', 'Reno', 'NV', 'USA', '89503', Decimal('3.96'), 1, 'Luís', 'Gonçalves', 'Embraer - Empresa Brasileira de Aeronáutica S.A.', 'Av. Brigadeiro Faria Lima, 2170', 'São José dos Campos', 'SP', 'Brazil', '12227-000', '+55 (12) 3923-5555', '+55 (12) 3923-5566', 'luisg@embraer.com.br', 3),
#  (16, 21, datetime.datetime(2009, 3, 5, 0, 0), '801 W 4th Street', 'Reno', 'NV', 'USA', '89503', Decimal('3.96'), 12, 'Roberto', 'Almeida', 'Riotur', 'Praça Pio X, 119', 'Rio de Janeiro', 'RJ', 'Brazil', '20040-020', '+55 (21) 2271-7000', '+55 (21) 2271-7070', 'roberto.almeida@riotur.gov.br', 3),
#  (17, 25, datetime.datetime(2009, 3, 6, 0, 0), '319 N. Frances Street', 'Madison', 'WI', 'USA', '53703', Decimal('5.94'), 11, 'Alexandre', 'Rocha', 'Banco do Brasil S.A.', 'Av. Paulista, 2022', 'São Paulo', 'SP', 'Brazil', '01310-200', '+55 (11) 3055-3278', '+55 (11) 3055-8131', 'alero@uol.com.br', 5),
#  (17, 25, datetime.datetime(2009, 3, 6, 0, 0), '319 N. Frances Street', 'Madison', 'WI', 'USA', '53703', Decimal('5.94'), 10, 'Eduardo', 'Martins', 'Woodstock Discos', 'Rua Dr. Falcão Filho, 155', 'São Paulo', 'SP', 'Brazil', '01007-010', '+55 (11) 3033-5446', '+55 (11) 3033-4564', 'eduardo@woodstock.com.br', 4),
#  (17, 25, datetime.datetime(2009, 3, 6, 0, 0), '319 N. Frances Street', 'Madison', 'WI', 'USA', '53703', Decimal('5.94'), 13, 'Fernanda', 'Ramos', None, 'Qe 7 Bloco G', 'Brasília', 'DF', 'Brazil', '71020-677', '+55 (61) 3363-5547', '+55 (61) 3363-7855', 'fernadaramos4@uol.com.br', 4),
#  (17, 25, datetime.datetime(2009, 3, 6, 0, 0), '319 N. Frances Street', 'Madison', 'WI', 'USA', '53703', Decimal('5.94'), 1, 'Luís', 'Gonçalves', 'Embraer - Empresa Brasileira de Aeronáutica S.A.', 'Av. Brigadeiro Faria Lima, 2170', 'São José dos Campos', 'SP', 'Brazil', '12227-000', '+55 (12) 3923-5555', '+55 (12) 3923-5566', 'luisg@embraer.com.br', 3),
#  (17, 25, datetime.datetime(2009, 3, 6, 0, 0), '319 N. Frances Street', 'Madison', 'WI', 'USA', '53703', Decimal('5.94'), 12, 'Roberto', 'Almeida', 'Riotur', 'Praça Pio X, 119', 'Rio de Janeiro', 'RJ', 'Brazil', '20040-020', '+55 (21) 2271-7000', '+55 (21) 2271-7070', 'roberto.almeida@riotur.gov.br', 3),
#  (18, 31, datetime.datetime(2009, 3, 9, 0, 0), '194A Chain Lake Drive', 'Halifax', 'NS', 'Canada', 'B3S 1C5', Decimal('8.91'), 11, 'Alexandre', 'Rocha', 'Banco do Brasil S.A.', 'Av. Paulista, 2022', 'São Paulo', 'SP', 'Brazil', '01310-200', '+55 (11) 3055-3278', '+55 (11) 3055-8131', 'alero@uol.com.br', 5),
#  (18, 31, datetime.datetime(2009, 3, 9, 0, 0), '194A Chain Lake Drive', 'Halifax', 'NS', 'Canada', 'B3S 1C5', Decimal('8.91'), 10, 'Eduardo', 'Martins', 'Woodstock Discos', 'Rua Dr. Falcão Filho, 155', 'São Paulo', 'SP', 'Brazil', '01007-010', '+55 (11) 3033-5446', '+55 (11) 3033-4564', 'eduardo@woodstock.com.br', 4),
#  (18, 31, datetime.datetime(2009, 3, 9, 0, 0), '194A Chain Lake Drive', 'Halifax', 'NS', 'Canada', 'B3S 1C5', Decimal('8.91'), 13, 'Fernanda', 'Ramos', None, 'Qe 7 Bloco G', 'Brasília', 'DF', 'Brazil', '71020-677', '+55 (61) 3363-5547', '+55 (61) 3363-7855', 'fernadaramos4@uol.com.br', 4),
#  (18, 31, datetime.datetime(2009, 3, 9, 0, 0), '194A Chain Lake Drive', 'Halifax', 'NS', 'Canada', 'B3S 1C5', Decimal('8.91'), 1, 'Luís', 'Gonçalves', 'Embraer - Empresa Brasileira de Aeronáutica S.A.', 'Av. Brigadeiro Faria Lima, 2170', 'São José dos Campos', 'SP', 'Brazil', '12227-000', '+55 (12) 3923-5555', '+55 (12) 3923-5566', 'luisg@embraer.com.br', 3),
#  (18, 31, datetime.datetime(2009, 3, 9, 0, 0), '194A Chain Lake Drive', 'Halifax', 'NS', 'Canada', 'B3S 1C5', Decimal('8.91'), 12, 'Roberto', 'Almeida', 'Riotur', 'Praça Pio X, 119', 'Rio de Janeiro', 'RJ', 'Brazil', '20040-020', '+55 (21) 2271-7000', '+55 (21) 2271-7070', 'roberto.almeida@riotur.gov.br', 3),
#  (19, 40, datetime.datetime(2009, 3, 14, 0, 0), '8, Rue Hanovre', 'Paris', None, 'France', '75002', Decimal('13.86'), 11, 'Alexandre', 'Rocha', 'Banco do Brasil S.A.', 'Av. Paulista, 2022', 'São Paulo', 'SP', 'Brazil', '01310-200', '+55 (11) 3055-3278', '+55 (11) 3055-8131', 'alero@uol.com.br', 5),
#  (19, 40, datetime.datetime(2009, 3, 14, 0, 0), '8, Rue Hanovre', 'Paris', None, 'France', '75002', Decimal('13.86'), 10, 'Eduardo', 'Martins', 'Woodstock Discos', 'Rua Dr. Falcão Filho, 155', 'São Paulo', 'SP', 'Brazil', '01007-010', '+55 (11) 3033-5446', '+55 (11) 3033-4564', 'eduardo@woodstock.com.br', 4),
#  (19, 40, datetime.datetime(2009, 3, 14, 0, 0), '8, Rue Hanovre', 'Paris', None, 'France', '75002', Decimal('13.86'), 13, 'Fernanda', 'Ramos', None, 'Qe 7 Bloco G', 'Brasília', 'DF', 'Brazil', '71020-677', '+55 (61) 3363-5547', '+55 (61) 3363-7855', 'fernadaramos4@uol.com.br', 4),
#  (19, 40, datetime.datetime(2009, 3, 14, 0, 0), '8, Rue Hanovre', 'Paris', None, 'France', '75002', Decimal('13.86'), 1, 'Luís', 'Gonçalves', 'Embraer - Empresa Brasileira de Aeronáutica S.A.', 'Av. Brigadeiro Faria Lima, 2170', 'São José dos Campos', 'SP', 'Brazil', '12227-000', '+55 (12) 3923-5555', '+55 (12) 3923-5566', 'luisg@embraer.com.br', 3),
#  (19, 40, datetime.datetime(2009, 3, 14, 0, 0), '8, Rue Hanovre', 'Paris', None, 'France', '75002', Decimal('13.86'), 12, 'Roberto', 'Almeida', 'Riotur', 'Praça Pio X, 119', 'Rio de Janeiro', 'RJ', 'Brazil', '20040-020', '+55 (21) 2271-7000', '+55 (21) 2271-7070', 'roberto.almeida@riotur.gov.br', 3),
#  (20, 54, datetime.datetime(2009, 3, 22, 0, 0), '110 Raeburn Pl', 'Edinburgh ', None, 'United Kingdom', 'EH4 1HH', Decimal('0.99'), 11, 'Alexandre', 'Rocha', 'Banco do Brasil S.A.', 'Av. Paulista, 2022', 'São Paulo', 'SP', 'Brazil', '01310-200', '+55 (11) 3055-3278', '+55 (11) 3055-8131', 'alero@uol.com.br', 5),
#  (20, 54, datetime.datetime(2009, 3, 22, 0, 0), '110 Raeburn Pl', 'Edinburgh ', None, 'United Kingdom', 'EH4 1HH', Decimal('0.99'), 10, 'Eduardo', 'Martins', 'Woodstock Discos', 'Rua Dr. Falcão Filho, 155', 'São Paulo', 'SP', 'Brazil', '01007-010', '+55 (11) 3033-5446', '+55 (11) 3033-4564', 'eduardo@woodstock.com.br', 4),
#  (20, 54, datetime.datetime(2009, 3, 22, 0, 0), '110 Raeburn Pl', 'Edinburgh ', None, 'United Kingdom', 'EH4 1HH', Decimal('0.99'), 13, 'Fernanda', 'Ramos', None, 'Qe 7 Bloco G', 'Brasília', 'DF', 'Brazil', '71020-677', '+55 (61) 3363-5547', '+55 (61) 3363-7855', 'fernadaramos4@uol.com.br', 4),
#  (20, 54, datetime.datetime(2009, 3, 22, 0, 0), '110 Raeburn Pl', 'Edinburgh ', None, 'United Kingdom', 'EH4 1HH', Decimal('0.99'), 1, 'Luís', 'Gonçalves', 'Embraer - Empresa Brasileira de Aeronáutica S.A.', 'Av. Brigadeiro Faria Lima, 2170', 'São José dos Campos', 'SP', 'Brazil', '12227-000', '+55 (12) 3923-5555', '+55 (12) 3923-5566', 'luisg@embraer.com.br', 3),
#  (20, 54, datetime.datetime(2009, 3, 22, 0, 0), '110 Raeburn Pl', 'Edinburgh ', None, 'United Kingdom', 'EH4 1HH', Decimal('0.99'), 12, 'Roberto', 'Almeida', 'Riotur', 'Praça Pio X, 119', 'Rio de Janeiro', 'RJ', 'Brazil', '20040-020', '+55 (21) 2271-7000', '+55 (21) 2271-7070', 'roberto.almeida@riotur.gov.br', 3),
#  (21, 55, datetime.datetime(2009, 4, 4, 0, 0), '421 Bourke Street', 'Sidney', 'NSW', 'Australia', '2010', Decimal('1.98'), 11, 'Alexandre', 'Rocha', 'Banco do Brasil S.A.', 'Av. Paulista, 2022', 'São Paulo', 'SP', 'Brazil', '01310-200', '+55 (11) 3055-3278', '+55 (11) 3055-8131', 'alero@uol.com.br', 5),
#  (21, 55, datetime.datetime(2009, 4, 4, 0, 0), '421 Bourke Street', 'Sidney', 'NSW', 'Australia', '2010', Decimal('1.98'), 10, 'Eduardo', 'Martins', 'Woodstock Discos', 'Rua Dr. Falcão Filho, 155', 'São Paulo', 'SP', 'Brazil', '01007-010', '+55 (11) 3033-5446', '+55 (11) 3033-4564', 'eduardo@woodstock.com.br', 4),
#  (21, 55, datetime.datetime(2009, 4, 4, 0, 0), '421 Bourke Street', 'Sidney', 'NSW', 'Australia', '2010', Decimal('1.98'), 13, 'Fernanda', 'Ramos', None, 'Qe 7 Bloco G', 'Brasília', 'DF', 'Brazil', '71020-677', '+55 (61) 3363-5547', '+55 (61) 3363-7855', 'fernadaramos4@uol.com.br', 4),
#  (21, 55, datetime.datetime(2009, 4, 4, 0, 0), '421 Bourke Street', 'Sidney', 'NSW', 'Australia', '2010', Decimal('1.98'), 1, 'Luís', 'Gonçalves', 'Embraer - Empresa Brasileira de Aeronáutica S.A.', 'Av. Brigadeiro Faria Lima, 2170', 'São José dos Campos', 'SP', 'Brazil', '12227-000', '+55 (12) 3923-5555', '+55 (12) 3923-5566', 'luisg@embraer.com.br', 3),
#  (21, 55, datetime.datetime(2009, 4, 4, 0, 0), '421 Bourke Street', 'Sidney', 'NSW', 'Australia', '2010', Decimal('1.98'), 12, 'Roberto', 'Almeida', 'Riotur', 'Praça Pio X, 119', 'Rio de Janeiro', 'RJ', 'Brazil', '20040-020', '+55 (21) 2271-7000', '+55 (21) 2271-7070', 'roberto.almeida@riotur.gov.br', 3),
#  (22, 57, datetime.datetime(2009, 4, 4, 0, 0), 'Calle Lira, 198', 'Santiago', None, 'Chile', None, Decimal('1.98'), 11, 'Alexandre', 'Rocha', 'Banco do Brasil S.A.', 'Av. Paulista, 2022', 'São Paulo', 'SP', 'Brazil', '01310-200', '+55 (11) 3055-3278', '+55 (11) 3055-8131', 'alero@uol.com.br', 5),
#  (22, 57, datetime.datetime(2009, 4, 4, 0, 0), 'Calle Lira, 198', 'Santiago', None, 'Chile', None, Decimal('1.98'), 10, 'Eduardo', 'Martins', 'Woodstock Discos', 'Rua Dr. Falcão Filho, 155', 'São Paulo', 'SP', 'Brazil', '01007-010', '+55 (11) 3033-5446', '+55 (11) 3033-4564', 'eduardo@woodstock.com.br', 4),
#  (22, 57, datetime.datetime(2009, 4, 4, 0, 0), 'Calle Lira, 198', 'Santiago', None, 'Chile', None, Decimal('1.98'), 13, 'Fernanda', 'Ramos', None, 'Qe 7 Bloco G', 'Brasília', 'DF', 'Brazil', '71020-677', '+55 (61) 3363-5547', '+55 (61) 3363-7855', 'fernadaramos4@uol.com.br', 4),
#  (22, 57, datetime.datetime(2009, 4, 4, 0, 0), 'Calle Lira, 198', 'Santiago', None, 'Chile', None, Decimal('1.98'), 1, 'Luís', 'Gonçalves', 'Embraer - Empresa Brasileira de Aeronáutica S.A.', 'Av. Brigadeiro Faria Lima, 2170', 'São José dos Campos', 'SP', 'Brazil', '12227-000', '+55 (12) 3923-5555', '+55 (12) 3923-5566', 'luisg@embraer.com.br', 3),
#  (22, 57, datetime.datetime(2009, 4, 4, 0, 0), 'Calle Lira, 198', 'Santiago', None, 'Chile', None, Decimal('1.98'), 12, 'Roberto', 'Almeida', 'Riotur', 'Praça Pio X, 119', 'Rio de Janeiro', 'RJ', 'Brazil', '20040-020', '+55 (21) 2271-7000', '+55 (21) 2271-7070', 'roberto.almeida@riotur.gov.br', 3),
#  (23, 59, datetime.datetime(2009, 4, 5, 0, 0), '3,Raj Bhavan Road', 'Bangalore', None, 'India', '560001', Decimal('3.96'), 11, 'Alexandre', 'Rocha', 'Banco do Brasil S.A.', 'Av. Paulista, 2022', 'São Paulo', 'SP', 'Brazil', '01310-200', '+55 (11) 3055-3278', '+55 (11) 3055-8131', 'alero@uol.com.br', 5),
#  (23, 59, datetime.datetime(2009, 4, 5, 0, 0), '3,Raj Bhavan Road', 'Bangalore', None, 'India', '560001', Decimal('3.96'), 10, 'Eduardo', 'Martins', 'Woodstock Discos', 'Rua Dr. Falcão Filho, 155', 'São Paulo', 'SP', 'Brazil', '01007-010', '+55 (11) 3033-5446', '+55 (11) 3033-4564', 'eduardo@woodstock.com.br', 4),
#  (23, 59, datetime.datetime(2009, 4, 5, 0, 0), '3,Raj Bhavan Road', 'Bangalore', None, 'India', '560001', Decimal('3.96'), 13, 'Fernanda', 'Ramos', None, 'Qe 7 Bloco G', 'Brasília', 'DF', 'Brazil', '71020-677', '+55 (61) 3363-5547', '+55 (61) 3363-7855', 'fernadaramos4@uol.com.br', 4),
#  (23, 59, datetime.datetime(2009, 4, 5, 0, 0), '3,Raj Bhavan Road', 'Bangalore', None, 'India', '560001', Decimal('3.96'), 1, 'Luís', 'Gonçalves', 'Embraer - Empresa Brasileira de Aeronáutica S.A.', 'Av. Brigadeiro Faria Lima, 2170', 'São José dos Campos', 'SP', 'Brazil', '12227-000', '+55 (12) 3923-5555', '+55 (12) 3923-5566', 'luisg@embraer.com.br', 3),
#  (23, 59, datetime.datetime(2009, 4, 5, 0, 0), '3,Raj Bhavan Road', 'Bangalore', None, 'India', '560001', Decimal('3.96'), 12, 'Roberto', 'Almeida', 'Riotur', 'Praça Pio X, 119', 'Rio de Janeiro', 'RJ', 'Brazil', '20040-020', '+55 (21) 2271-7000', '+55 (21) 2271-7070', 'roberto.almeida@riotur.gov.br', 3),
#  (24, 4, datetime.datetime(2009, 4, 6, 0, 0), 'Ullevålsveien 14', 'Oslo', None, 'Norway', '0171', Decimal('5.94'), 11, 'Alexandre', 'Rocha', 'Banco do Brasil S.A.', 'Av. Paulista, 2022', 'São Paulo', 'SP', 'Brazil', '01310-200', '+55 (11) 3055-3278', '+55 (11) 3055-8131', 'alero@uol.com.br', 5),
#  (24, 4, datetime.datetime(2009, 4, 6, 0, 0), 'Ullevålsveien 14', 'Oslo', None, 'Norway', '0171', Decimal('5.94'), 10, 'Eduardo', 'Martins', 'Woodstock Discos', 'Rua Dr. Falcão Filho, 155', 'São Paulo', 'SP', 'Brazil', '01007-010', '+55 (11) 3033-5446', '+55 (11) 3033-4564', 'eduardo@woodstock.com.br', 4),
#  (24, 4, datetime.datetime(2009, 4, 6, 0, 0), 'Ullevålsveien 14', 'Oslo', None, 'Norway', '0171', Decimal('5.94'), 13, 'Fernanda', 'Ramos', None, 'Qe 7 Bloco G', 'Brasília', 'DF', 'Brazil', '71020-677', '+55 (61) 3363-5547', '+55 (61) 3363-7855', 'fernadaramos4@uol.com.br', 4),
#  (24, 4, datetime.datetime(2009, 4, 6, 0, 0), 'Ullevålsveien 14', 'Oslo', None, 'Norway', '0171', Decimal('5.94'), 1, 'Luís', 'Gonçalves', 'Embraer - Empresa Brasileira de Aeronáutica S.A.', 'Av. Brigadeiro Faria Lima, 2170', 'São José dos Campos', 'SP', 'Brazil', '12227-000', '+55 (12) 3923-5555', '+55 (12) 3923-5566', 'luisg@embraer.com.br', 3),
#  (24, 4, datetime.datetime(2009, 4, 6, 0, 0), 'Ullevålsveien 14', 'Oslo', None, 'Norway', '0171', Decimal('5.94'), 12, 'Roberto', 'Almeida', 'Riotur', 'Praça Pio X, 119', 'Rio de Janeiro', 'RJ', 'Brazil', '20040-020', '+55 (21) 2271-7000', '+55 (21) 2271-7070', 'roberto.almeida@riotur.gov.br', 3),
#  (25, 10, datetime.datetime(2009, 4, 9, 0, 0), 'Rua Dr. Falcão Filho, 155', 'São Paulo', 'SP', 'Brazil', '01007-010', Decimal('8.91'), 11, 'Alexandre', 'Rocha', 'Banco do Brasil S.A.', 'Av. Paulista, 2022', 'São Paulo', 'SP', 'Brazil', '01310-200', '+55 (11) 3055-3278', '+55 (11) 3055-8131', 'alero@uol.com.br', 5),
#  (25, 10, datetime.datetime(2009, 4, 9, 0, 0), 'Rua Dr. Falcão Filho, 155', 'São Paulo', 'SP', 'Brazil', '01007-010', Decimal('8.91'), 10, 'Eduardo', 'Martins', 'Woodstock Discos', 'Rua Dr. Falcão Filho, 155', 'São Paulo', 'SP', 'Brazil', '01007-010', '+55 (11) 3033-5446', '+55 (11) 3033-4564', 'eduardo@woodstock.com.br', 4),
#  (25, 10, datetime.datetime(2009, 4, 9, 0, 0), 'Rua Dr. Falcão Filho, 155', 'São Paulo', 'SP', 'Brazil', '01007-010', Decimal('8.91'), 13, 'Fernanda', 'Ramos', None, 'Qe 7 Bloco G', 'Brasília', 'DF', 'Brazil', '71020-677', '+55 (61) 3363-5547', '+55 (61) 3363-7855', 'fernadaramos4@uol.com.br', 4),
#  (25, 10, datetime.datetime(2009, 4, 9, 0, 0), 'Rua Dr. Falcão Filho, 155', 'São Paulo', 'SP', 'Brazil', '01007-010', Decimal('8.91'), 1, 'Luís', 'Gonçalves', 'Embraer - Empresa Brasileira de Aeronáutica S.A.', 'Av. Brigadeiro Faria Lima, 2170', 'São José dos Campos', 'SP', 'Brazil', '12227-000', '+55 (12) 3923-5555', '+55 (12) 3923-5566', 'luisg@embraer.com.br', 3),
#  (25, 10, datetime.datetime(2009, 4, 9, 0, 0), 'Rua Dr. Falcão Filho, 155', 'São Paulo', 'SP', 'Brazil', '01007-010', Decimal('8.91'), 12, 'Roberto', 'Almeida', 'Riotur', 'Praça Pio X, 119', 'Rio de Janeiro', 'RJ', 'Brazil', '20040-020', '+55 (21) 2271-7000', '+55 (21) 2271-7070', 'roberto.almeida@riotur.gov.br', 3),
#  (26, 19, datetime.datetime(2009, 4, 14, 0, 0), '1 Infinite Loop', 'Cupertino', 'CA', 'USA', '95014', Decimal('13.86'), 11, 'Alexandre', 'Rocha', 'Banco do Brasil S.A.', 'Av. Paulista, 2022', 'São Paulo', 'SP', 'Brazil', '01310-200', '+55 (11) 3055-3278', '+55 (11) 3055-8131', 'alero@uol.com.br', 5),
#  (26, 19, datetime.datetime(2009, 4, 14, 0, 0), '1 Infinite Loop', 'Cupertino', 'CA', 'USA', '95014', Decimal('13.86'), 10, 'Eduardo', 'Martins', 'Woodstock Discos', 'Rua Dr. Falcão Filho, 155', 'São Paulo', 'SP', 'Brazil', '01007-010', '+55 (11) 3033-5446', '+55 (11) 3033-4564', 'eduardo@woodstock.com.br', 4),
#  (26, 19, datetime.datetime(2009, 4, 14, 0, 0), '1 Infinite Loop', 'Cupertino', 'CA', 'USA', '95014', Decimal('13.86'), 13, 'Fernanda', 'Ramos', None, 'Qe 7 Bloco G', 'Brasília', 'DF', 'Brazil', '71020-677', '+55 (61) 3363-5547', '+55 (61) 3363-7855', 'fernadaramos4@uol.com.br', 4),
#  (26, 19, datetime.datetime(2009, 4, 14, 0, 0), '1 Infinite Loop', 'Cupertino', 'CA', 'USA', '95014', Decimal('13.86'), 1, 'Luís', 'Gonçalves', 'Embraer - Empresa Brasileira de Aeronáutica S.A.', 'Av. Brigadeiro Faria Lima, 2170', 'São José dos Campos', 'SP', 'Brazil', '12227-000', '+55 (12) 3923-5555', '+55 (12) 3923-5566', 'luisg@embraer.com.br', 3),
#  (26, 19, datetime.datetime(2009, 4, 14, 0, 0), '1 Infinite Loop', 'Cupertino', 'CA', 'USA', '95014', Decimal('13.86'), 12, 'Roberto', 'Almeida', 'Riotur', 'Praça Pio X, 119', 'Rio de Janeiro', 'RJ', 'Brazil', '20040-020', '+55 (21) 2271-7000', '+55 (21) 2271-7070', 'roberto.almeida@riotur.gov.br', 3),
#  (27, 33, datetime.datetime(2009, 4, 22, 0, 0), '5112 48 Street', 'Yellowknife', 'NT', 'Canada', 'X1A 1N6', Decimal('0.99'), 11, 'Alexandre', 'Rocha', 'Banco do Brasil S.A.', 'Av. Paulista, 2022', 'São Paulo', 'SP', 'Brazil', '01310-200', '+55 (11) 3055-3278', '+55 (11) 3055-8131', 'alero@uol.com.br', 5),
#  (27, 33, datetime.datetime(2009, 4, 22, 0, 0), '5112 48 Street', 'Yellowknife', 'NT', 'Canada', 'X1A 1N6', Decimal('0.99'), 10, 'Eduardo', 'Martins', 'Woodstock Discos', 'Rua Dr. Falcão Filho, 155', 'São Paulo', 'SP', 'Brazil', '01007-010', '+55 (11) 3033-5446', '+55 (11) 3033-4564', 'eduardo@woodstock.com.br', 4),
#  (27, 33, datetime.datetime(2009, 4, 22, 0, 0), '5112 48 Street', 'Yellowknife', 'NT', 'Canada', 'X1A 1N6', Decimal('0.99'), 13, 'Fernanda', 'Ramos', None, 'Qe 7 Bloco G', 'Brasília', 'DF', 'Brazil', '71020-677', '+55 (61) 3363-5547', '+55 (61) 3363-7855', 'fernadaramos4@uol.com.br', 4),
#  (27, 33, datetime.datetime(2009, 4, 22, 0, 0), '5112 48 Street', 'Yellowknife', 'NT', 'Canada', 'X1A 1N6', Decimal('0.99'), 1, 'Luís', 'Gonçalves', 'Embraer - Empresa Brasileira de Aeronáutica S.A.', 'Av. Brigadeiro Faria Lima, 2170', 'São José dos Campos', 'SP', 'Brazil', '12227-000', '+55 (12) 3923-5555', '+55 (12) 3923-5566', 'luisg@embraer.com.br', 3),
#  (27, 33, datetime.datetime(2009, 4, 22, 0, 0), '5112 48 Street', 'Yellowknife', 'NT', 'Canada', 'X1A 1N6', Decimal('0.99'), 12, 'Roberto', 'Almeida', 'Riotur', 'Praça Pio X, 119', 'Rio de Janeiro', 'RJ', 'Brazil', '20040-020', '+55 (21) 2271-7000', '+55 (21) 2271-7070', 'roberto.almeida@riotur.gov.br', 3),
#  (28, 34, datetime.datetime(2009, 5, 5, 0, 0), 'Rua da Assunção 53', 'Lisbon', None, 'Portugal', None, Decimal('1.98'), 11, 'Alexandre', 'Rocha', 'Banco do Brasil S.A.', 'Av. Paulista, 2022', 'São Paulo', 'SP', 'Brazil', '01310-200', '+55 (11) 3055-3278', '+55 (11) 3055-8131', 'alero@uol.com.br', 5),
#  (28, 34, datetime.datetime(2009, 5, 5, 0, 0), 'Rua da Assunção 53', 'Lisbon', None, 'Portugal', None, Decimal('1.98'), 10, 'Eduardo', 'Martins', 'Woodstock Discos', 'Rua Dr. Falcão Filho, 155', 'São Paulo', 'SP', 'Brazil', '01007-010', '+55 (11) 3033-5446', '+55 (11) 3033-4564', 'eduardo@woodstock.com.br', 4),
#  (28, 34, datetime.datetime(2009, 5, 5, 0, 0), 'Rua da Assunção 53', 'Lisbon', None, 'Portugal', None, Decimal('1.98'), 13, 'Fernanda', 'Ramos', None, 'Qe 7 Bloco G', 'Brasília', 'DF', 'Brazil', '71020-677', '+55 (61) 3363-5547', '+55 (61) 3363-7855', 'fernadaramos4@uol.com.br', 4),
#  (28, 34, datetime.datetime(2009, 5, 5, 0, 0), 'Rua da Assunção 53', 'Lisbon', None, 'Portugal', None, Decimal('1.98'), 1, 'Luís', 'Gonçalves', 'Embraer - Empresa Brasileira de Aeronáutica S.A.', 'Av. Brigadeiro Faria Lima, 2170', 'São José dos Campos', 'SP', 'Brazil', '12227-000', '+55 (12) 3923-5555', '+55 (12) 3923-5566', 'luisg@embraer.com.br', 3),
#  (28, 34, datetime.datetime(2009, 5, 5, 0, 0), 'Rua da Assunção 53', 'Lisbon', None, 'Portugal', None, Decimal('1.98'), 12, 'Roberto', 'Almeida', 'Riotur', 'Praça Pio X, 119', 'Rio de Janeiro', 'RJ', 'Brazil', '20040-020', '+55 (21) 2271-7000', '+55 (21) 2271-7070', 'roberto.almeida@riotur.gov.br', 3),
#  (29, 36, datetime.datetime(2009, 5, 5, 0, 0), 'Tauentzienstraße 8', 'Berlin', None, 'Germany', '10789', Decimal('1.98'), 11, 'Alexandre', 'Rocha', 'Banco do Brasil S.A.', 'Av. Paulista, 2022', 'São Paulo', 'SP', 'Brazil', '01310-200', '+55 (11) 3055-3278', '+55 (11) 3055-8131', 'alero@uol.com.br', 5),
#  (29, 36, datetime.datetime(2009, 5, 5, 0, 0), 'Tauentzienstraße 8', 'Berlin', None, 'Germany', '10789', Decimal('1.98'), 10, 'Eduardo', 'Martins', 'Woodstock Discos', 'Rua Dr. Falcão Filho, 155', 'São Paulo', 'SP', 'Brazil', '01007-010', '+55 (11) 3033-5446', '+55 (11) 3033-4564', 'eduardo@woodstock.com.br', 4),
#  (29, 36, datetime.datetime(2009, 5, 5, 0, 0), 'Tauentzienstraße 8', 'Berlin', None, 'Germany', '10789', Decimal('1.98'), 13, 'Fernanda', 'Ramos', None, 'Qe 7 Bloco G', 'Brasília', 'DF', 'Brazil', '71020-677', '+55 (61) 3363-5547', '+55 (61) 3363-7855', 'fernadaramos4@uol.com.br', 4),
#  (29, 36, datetime.datetime(2009, 5, 5, 0, 0), 'Tauentzienstraße 8', 'Berlin', None, 'Germany', '10789', Decimal('1.98'), 1, 'Luís', 'Gonçalves', 'Embraer - Empresa Brasileira de Aeronáutica S.A.', 'Av. Brigadeiro Faria Lima, 2170', 'São José dos Campos', 'SP', 'Brazil', '12227-000', '+55 (12) 3923-5555', '+55 (12) 3923-5566', 'luisg@embraer.com.br', 3),
#  (29, 36, datetime.datetime(2009, 5, 5, 0, 0), 'Tauentzienstraße 8', 'Berlin', None, 'Germany', '10789', Decimal('1.98'), 12, 'Roberto', 'Almeida', 'Riotur', 'Praça Pio X, 119', 'Rio de Janeiro', 'RJ', 'Brazil', '20040-020', '+55 (21) 2271-7000', '+55 (21) 2271-7070', 'roberto.almeida@riotur.gov.br', 3),
#  (30, 38, datetime.datetime(2009, 5, 6, 0, 0), 'Barbarossastraße 19', 'Berlin', None, 'Germany', '10779', Decimal('3.96'), 11, 'Alexandre', 'Rocha', 'Banco do Brasil S.A.', 'Av. Paulista, 2022', 'São Paulo', 'SP', 'Brazil', '01310-200', '+55 (11) 3055-3278', '+55 (11) 3055-8131', 'alero@uol.com.br', 5),
#  (30, 38, datetime.datetime(2009, 5, 6, 0, 0), 'Barbarossastraße 19', 'Berlin', None, 'Germany', '10779', Decimal('3.96'), 10, 'Eduardo', 'Martins', 'Woodstock Discos', 'Rua Dr. Falcão Filho, 155', 'São Paulo', 'SP', 'Brazil', '01007-010', '+55 (11) 3033-5446', '+55 (11) 3033-4564', 'eduardo@woodstock.com.br', 4),
#  (30, 38, datetime.datetime(2009, 5, 6, 0, 0), 'Barbarossastraße 19', 'Berlin', None, 'Germany', '10779', Decimal('3.96'), 13, 'Fernanda', 'Ramos', None, 'Qe 7 Bloco G', 'Brasília', 'DF', 'Brazil', '71020-677', '+55 (61) 3363-5547', '+55 (61) 3363-7855', 'fernadaramos4@uol.com.br', 4),
#  (30, 38, datetime.datetime(2009, 5, 6, 0, 0), 'Barbarossastraße 19', 'Berlin', None, 'Germany', '10779', Decimal('3.96'), 1, 'Luís', 'Gonçalves', 'Embraer - Empresa Brasileira de Aeronáutica S.A.', 'Av. Brigadeiro Faria Lima, 2170', 'São José dos Campos', 'SP', 'Brazil', '12227-000', '+55 (12) 3923-5555', '+55 (12) 3923-5566', 'luisg@embraer.com.br', 3),
#  (30, 38, datetime.datetime(2009, 5, 6, 0, 0), 'Barbarossastraße 19', 'Berlin', None, 'Germany', '10779', Decimal('3.96'), 12, 'Roberto', 'Almeida', 'Riotur', 'Praça Pio X, 119', 'Rio de Janeiro', 'RJ', 'Brazil', '20040-020', '+55 (21) 2271-7000', '+55 (21) 2271-7070', 'roberto.almeida@riotur.gov.br', 3),
#  (31, 42, datetime.datetime(2009, 5, 7, 0, 0), '9, Place Louis Barthou', 'Bordeaux', None, 'France', '33000', Decimal('5.94'), 11, 'Alexandre', 'Rocha', 'Banco do Brasil S.A.', 'Av. Paulista, 2022', 'São Paulo', 'SP', 'Brazil', '01310-200', '+55 (11) 3055-3278', '+55 (11) 3055-8131', 'alero@uol.com.br', 5),
#  (31, 42, datetime.datetime(2009, 5, 7, 0, 0), '9, Place Louis Barthou', 'Bordeaux', None, 'France', '33000', Decimal('5.94'), 10, 'Eduardo', 'Martins', 'Woodstock Discos', 'Rua Dr. Falcão Filho, 155', 'São Paulo', 'SP', 'Brazil', '01007-010', '+55 (11) 3033-5446', '+55 (11) 3033-4564', 'eduardo@woodstock.com.br', 4),
# ...
#  (191, 27, datetime.datetime(2011, 4, 19, 0, 0), '1033 N Park Ave', 'Tucson', 'AZ', 'USA', '85719', Decimal('3.96'), 10, 'Eduardo', 'Martins', 'Woodstock Discos', 'Rua Dr. Falcão Filho, 155', 'São Paulo', 'SP', 'Brazil', '01007-010', '+55 (11) 3033-5446', '+55 (11) 3033-4564', 'eduardo@woodstock.com.br', 4),
#  (191, 27, datetime.datetime(2011, 4, 19, 0, 0), '1033 N Park Ave', 'Tucson', 'AZ', 'USA', '85719', Decimal('3.96'), 13, 'Fernanda', 'Ramos', None, 'Qe 7 Bloco G', 'Brasília', 'DF', 'Brazil', '71020-677', '+55 (61) 3363-5547', '+55 (61) 3363-7855', 'fernadaramos4@uol.com.br', 4),
#  (191, 27, datetime.datetime(2011, 4, 19, 0, 0), '1033 N Park Ave', 'Tucson', 'AZ', 'USA', '85719', Decimal('3.96'), 1, 'Luís', 'Gonçalves', 'Embraer - Empresa Brasileira de Aeronáutica S.A.', 'Av. Brigadeiro Faria Lima, 2170', 'São José dos Campos', 'SP', 'Brazil', '12227-000', '+55 (12) 3923-5555', '+55 (12) 3923-5566', 'luisg@embraer.com.br', 3),
#  (191, 27, datetime.datetime(2011, 4, 19, 0, 0), '1033 N Park Ave', 'Tucson', 'AZ', 'USA', '85719', Decimal('3.96'), 12, 'Roberto', 'Almeida', 'Riotur', 'Praça Pio X, 119', 'Rio de Janeiro', 'RJ', 'Brazil', '20040-020', '+55 (21) 2271-7000', '+55 (21) 2271-7070', 'roberto.almeida@riotur.gov.br', 3),
#  (192, 31, datetime.datetime(2011, 4, 20, 0, 0), '194A Chain Lake Drive', 'Halifax', 'NS', 'Canada', 'B3S 1C5', Decimal('5.94'), 11, 'Alexandre', 'Rocha', 'Banco do Brasil S.A.', 'Av. Paulista, 2022', 'São Paulo', 'SP', 'Brazil', '01310-200', '+55 (11) 3055-3278', '+55 (11) 3055-8131', 'alero@uol.com.br', 5),
#  (192, 31, datetime.datetime(2011, 4, 20, 0, 0), '194A Chain Lake Drive', 'Halifax', 'NS', 'Canada', 'B3S 1C5', Decimal('5.94'), 10, 'Eduardo', 'Martins', 'Woodstock Discos', 'Rua Dr. Falcão Filho, 155', 'São Paulo', 'SP', 'Brazil', '01007-010', '+55 (11) 3033-5446', '+55 (11) 3033-4564', 'eduardo@woodstock.com.br', 4),
#  (192, 31, datetime.datetime(2011, 4, 20, 0, 0), '194A Chain Lake Drive', 'Halifax', 'NS', 'Canada', 'B3S 1C5', Decimal('5.94'), 13, 'Fernanda', 'Ramos', None, 'Qe 7 Bloco G', 'Brasília', 'DF', 'Brazil', '71020-677', '+55 (61) 3363-5547', '+55 (61) 3363-7855', 'fernadaramos4@uol.com.br', 4),
#  (192, 31, datetime.datetime(2011, 4, 20, 0, 0), '194A Chain Lake Drive', 'Halifax', 'NS', 'Canada', 'B3S 1C5', Decimal('5.94'), 1, 'Luís', 'Gonçalves', 'Embraer - Empresa Brasileira de Aeronáutica S.A.', 'Av. Brigadeiro Faria Lima, 2170', 'São José dos Campos', 'SP', 'Brazil', '12227-000', '+55 (12) 3923-5555', '+55 (12) 3923-5566', 'luisg@embraer.com.br', 3),
#  (192, 31, datetime.datetime(2011, 4, 20, 0, 0), '194A Chain Lake Drive', 'Halifax', 'NS', 'Canada', 'B3S 1C5', Decimal('5.94'), 12, 'Roberto', 'Almeida', 'Riotur', 'Praça Pio X, 119', 'Rio de Janeiro', 'RJ', 'Brazil', '20040-020', '+55 (21) 2271-7000', '+55 (21) 2271-7070', 'roberto.almeida@riotur.gov.br', 3),
#  (193, 37, datetime.datetime(2011, 4, 23, 0, 0), 'Berger Straße 10', 'Frankfurt', None, 'Germany', '60316', Decimal('14.91'), 11, 'Alexandre', 'Rocha', 'Banco do Brasil S.A.', 'Av. Paulista, 2022', 'São Paulo', 'SP', 'Brazil', '01310-200', '+55 (11) 3055-3278', '+55 (11) 3055-8131', 'alero@uol.com.br', 5),
#  (193, 37, datetime.datetime(2011, 4, 23, 0, 0), 'Berger Straße 10', 'Frankfurt', None, 'Germany', '60316', Decimal('14.91'), 10, 'Eduardo', 'Martins', 'Woodstock Discos', 'Rua Dr. Falcão Filho, 155', 'São Paulo', 'SP', 'Brazil', '01007-010', '+55 (11) 3033-5446', '+55 (11) 3033-4564', 'eduardo@woodstock.com.br', 4),
#  (193, 37, datetime.datetime(2011, 4, 23, 0, 0), 'Berger Straße 10', 'Frankfurt', None, 'Germany', '60316', Decimal('14.91'), 13, 'Fernanda', 'Ramos', None, 'Qe 7 Bloco G', 'Brasília', 'DF', 'Brazil', '71020-677', '+55 (61) 3363-5547', '+55 (61) 3363-7855', 'fernadaramos4@uol.com.br', 4),
#  (193, 37, datetime.datetime(2011, 4, 23, 0, 0), 'Berger Straße 10', 'Frankfurt', None, 'Germany', '60316', Decimal('14.91'), 1, 'Luís', 'Gonçalves', 'Embraer - Empresa Brasileira de Aeronáutica S.A.', 'Av. Brigadeiro Faria Lima, 2170', 'São José dos Campos', 'SP', 'Brazil', '12227-000', '+55 (12) 3923-5555', '+55 (12) 3923-5566', 'luisg@embraer.com.br', 3),
#  (193, 37, datetime.datetime(2011, 4, 23, 0, 0), 'Berger Straße 10', 'Frankfurt', None, 'Germany', '60316', Decimal('14.91'), 12, 'Roberto', 'Almeida', 'Riotur', 'Praça Pio X, 119', 'Rio de Janeiro', 'RJ', 'Brazil', '20040-020', '+55 (21) 2271-7000', '+55 (21) 2271-7070', 'roberto.almeida@riotur.gov.br', 3),
#  (194, 46, datetime.datetime(2011, 4, 28, 0, 0), '3 Chatham Street', 'Dublin', 'Dublin', 'Ireland', None, Decimal('21.86'), 11, 'Alexandre', 'Rocha', 'Banco do Brasil S.A.', 'Av. Paulista, 2022', 'São Paulo', 'SP', 'Brazil', '01310-200', '+55 (11) 3055-3278', '+55 (11) 3055-8131', 'alero@uol.com.br', 5),
#  (194, 46, datetime.datetime(2011, 4, 28, 0, 0), '3 Chatham Street', 'Dublin', 'Dublin', 'Ireland', None, Decimal('21.86'), 10, 'Eduardo', 'Martins', 'Woodstock Discos', 'Rua Dr. Falcão Filho, 155', 'São Paulo', 'SP', 'Brazil', '01007-010', '+55 (11) 3033-5446', '+55 (11) 3033-4564', 'eduardo@woodstock.com.br', 4),
#  (194, 46, datetime.datetime(2011, 4, 28, 0, 0), '3 Chatham Street', 'Dublin', 'Dublin', 'Ireland', None, Decimal('21.86'), 13, 'Fernanda', 'Ramos', None, 'Qe 7 Bloco G', 'Brasília', 'DF', 'Brazil', '71020-677', '+55 (61) 3363-5547', '+55 (61) 3363-7855', 'fernadaramos4@uol.com.br', 4),
#  (194, 46, datetime.datetime(2011, 4, 28, 0, 0), '3 Chatham Street', 'Dublin', 'Dublin', 'Ireland', None, Decimal('21.86'), 1, 'Luís', 'Gonçalves', 'Embraer - Empresa Brasileira de Aeronáutica S.A.', 'Av. Brigadeiro Faria Lima, 2170', 'São José dos Campos', 'SP', 'Brazil', '12227-000', '+55 (12) 3923-5555', '+55 (12) 3923-5566', 'luisg@embraer.com.br', 3),
#  (194, 46, datetime.datetime(2011, 4, 28, 0, 0), '3 Chatham Street', 'Dublin', 'Dublin', 'Ireland', None, Decimal('21.86'), 12, 'Roberto', 'Almeida', 'Riotur', 'Praça Pio X, 119', 'Rio de Janeiro', 'RJ', 'Brazil', '20040-020', '+55 (21) 2271-7000', '+55 (21) 2271-7070', 'roberto.almeida@riotur.gov.br', 3),
#  (195, 1, datetime.datetime(2011, 5, 6, 0, 0), 'Av. Brigadeiro Faria Lima, 2170', 'São José dos Campos', 'SP', 'Brazil', '12227-000', Decimal('0.99'), 11, 'Alexandre', 'Rocha', 'Banco do Brasil S.A.', 'Av. Paulista, 2022', 'São Paulo', 'SP', 'Brazil', '01310-200', '+55 (11) 3055-3278', '+55 (11) 3055-8131', 'alero@uol.com.br', 5),
#  (195, 1, datetime.datetime(2011, 5, 6, 0, 0), 'Av. Brigadeiro Faria Lima, 2170', 'São José dos Campos', 'SP', 'Brazil', '12227-000', Decimal('0.99'), 10, 'Eduardo', 'Martins', 'Woodstock Discos', 'Rua Dr. Falcão Filho, 155', 'São Paulo', 'SP', 'Brazil', '01007-010', '+55 (11) 3033-5446', '+55 (11) 3033-4564', 'eduardo@woodstock.com.br', 4),
#  (195, 1, datetime.datetime(2011, 5, 6, 0, 0), 'Av. Brigadeiro Faria Lima, 2170', 'São José dos Campos', 'SP', 'Brazil', '12227-000', Decimal('0.99'), 13, 'Fernanda', 'Ramos', None, 'Qe 7 Bloco G', 'Brasília', 'DF', 'Brazil', '71020-677', '+55 (61) 3363-5547', '+55 (61) 3363-7855', 'fernadaramos4@uol.com.br', 4),
#  (195, 1, datetime.datetime(2011, 5, 6, 0, 0), 'Av. Brigadeiro Faria Lima, 2170', 'São José dos Campos', 'SP', 'Brazil', '12227-000', Decimal('0.99'), 1, 'Luís', 'Gonçalves', 'Embraer - Empresa Brasileira de Aeronáutica S.A.', 'Av. Brigadeiro Faria Lima, 2170', 'São José dos Campos', 'SP', 'Brazil', '12227-000', '+55 (12) 3923-5555', '+55 (12) 3923-5566', 'luisg@embraer.com.br', 3),
#  (195, 1, datetime.datetime(2011, 5, 6, 0, 0), 'Av. Brigadeiro Faria Lima, 2170', 'São José dos Campos', 'SP', 'Brazil', '12227-000', Decimal('0.99'), 12, 'Roberto', 'Almeida', 'Riotur', 'Praça Pio X, 119', 'Rio de Janeiro', 'RJ', 'Brazil', '20040-020', '+55 (21) 2271-7000', '+55 (21) 2271-7070', 'roberto.almeida@riotur.gov.br', 3),
#  (196, 2, datetime.datetime(2011, 5, 19, 0, 0), 'Theodor-Heuss-Straße 34', 'Stuttgart', None, 'Germany', '70174', Decimal('1.98'), 11, 'Alexandre', 'Rocha', 'Banco do Brasil S.A.', 'Av. Paulista, 2022', 'São Paulo', 'SP', 'Brazil', '01310-200', '+55 (11) 3055-3278', '+55 (11) 3055-8131', 'alero@uol.com.br', 5),
#  (196, 2, datetime.datetime(2011, 5, 19, 0, 0), 'Theodor-Heuss-Straße 34', 'Stuttgart', None, 'Germany', '70174', Decimal('1.98'), 10, 'Eduardo', 'Martins', 'Woodstock Discos', 'Rua Dr. Falcão Filho, 155', 'São Paulo', 'SP', 'Brazil', '01007-010', '+55 (11) 3033-5446', '+55 (11) 3033-4564', 'eduardo@woodstock.com.br', 4),
#  (196, 2, datetime.datetime(2011, 5, 19, 0, 0), 'Theodor-Heuss-Straße 34', 'Stuttgart', None, 'Germany', '70174', Decimal('1.98'), 13, 'Fernanda', 'Ramos', None, 'Qe 7 Bloco G', 'Brasília', 'DF', 'Brazil', '71020-677', '+55 (61) 3363-5547', '+55 (61) 3363-7855', 'fernadaramos4@uol.com.br', 4),
#  (196, 2, datetime.datetime(2011, 5, 19, 0, 0), 'Theodor-Heuss-Straße 34', 'Stuttgart', None, 'Germany', '70174', Decimal('1.98'), 1, 'Luís', 'Gonçalves', 'Embraer - Empresa Brasileira de Aeronáutica S.A.', 'Av. Brigadeiro Faria Lima, 2170', 'São José dos Campos', 'SP', 'Brazil', '12227-000', '+55 (12) 3923-5555', '+55 (12) 3923-5566', 'luisg@embraer.com.br', 3),
#  (196, 2, datetime.datetime(2011, 5, 19, 0, 0), 'Theodor-Heuss-Straße 34', 'Stuttgart', None, 'Germany', '70174', Decimal('1.98'), 12, 'Roberto', 'Almeida', 'Riotur', 'Praça Pio X, 119', 'Rio de Janeiro', 'RJ', 'Brazil', '20040-020', '+55 (21) 2271-7000', '+55 (21) 2271-7070', 'roberto.almeida@riotur.gov.br', 3),
#  (197, 4, datetime.datetime(2011, 5, 19, 0, 0), 'Ullevålsveien 14', 'Oslo', None, 'Norway', '0171', Decimal('1.98'), 11, 'Alexandre', 'Rocha', 'Banco do Brasil S.A.', 'Av. Paulista, 2022', 'São Paulo', 'SP', 'Brazil', '01310-200', '+55 (11) 3055-3278', '+55 (11) 3055-8131', 'alero@uol.com.br', 5),
#  (197, 4, datetime.datetime(2011, 5, 19, 0, 0), 'Ullevålsveien 14', 'Oslo', None, 'Norway', '0171', Decimal('1.98'), 10, 'Eduardo', 'Martins', 'Woodstock Discos', 'Rua Dr. Falcão Filho, 155', 'São Paulo', 'SP', 'Brazil', '01007-010', '+55 (11) 3033-5446', '+55 (11) 3033-4564', 'eduardo@woodstock.com.br', 4),
#  (197, 4, datetime.datetime(2011, 5, 19, 0, 0), 'Ullevålsveien 14', 'Oslo', None, 'Norway', '0171', Decimal('1.98'), 13, 'Fernanda', 'Ramos', None, 'Qe 7 Bloco G', 'Brasília', 'DF', 'Brazil', '71020-677', '+55 (61) 3363-5547', '+55 (61) 3363-7855', 'fernadaramos4@uol.com.br', 4),
#  (197, 4, datetime.datetime(2011, 5, 19, 0, 0), 'Ullevålsveien 14', 'Oslo', None, 'Norway', '0171', Decimal('1.98'), 1, 'Luís', 'Gonçalves', 'Embraer - Empresa Brasileira de Aeronáutica S.A.', 'Av. Brigadeiro Faria Lima, 2170', 'São José dos Campos', 'SP', 'Brazil', '12227-000', '+55 (12) 3923-5555', '+55 (12) 3923-5566', 'luisg@embraer.com.br', 3),
#  (197, 4, datetime.datetime(2011, 5, 19, 0, 0), 'Ullevålsveien 14', 'Oslo', None, 'Norway', '0171', Decimal('1.98'), 12, 'Roberto', 'Almeida', 'Riotur', 'Praça Pio X, 119', 'Rio de Janeiro', 'RJ', 'Brazil', '20040-020', '+55 (21) 2271-7000', '+55 (21) 2271-7070', 'roberto.almeida@riotur.gov.br', 3),
#  (198, 6, datetime.datetime(2011, 5, 20, 0, 0), 'Rilská 3174/6', 'Prague', None, 'Czech Republic', '14300', Decimal('3.96'), 11, 'Alexandre', 'Rocha', 'Banco do Brasil S.A.', 'Av. Paulista, 2022', 'São Paulo', 'SP', 'Brazil', '01310-200', '+55 (11) 3055-3278', '+55 (11) 3055-8131', 'alero@uol.com.br', 5),
#  (198, 6, datetime.datetime(2011, 5, 20, 0, 0), 'Rilská 3174/6', 'Prague', None, 'Czech Republic', '14300', Decimal('3.96'), 10, 'Eduardo', 'Martins', 'Woodstock Discos', 'Rua Dr. Falcão Filho, 155', 'São Paulo', 'SP', 'Brazil', '01007-010', '+55 (11) 3033-5446', '+55 (11) 3033-4564', 'eduardo@woodstock.com.br', 4),
#  (198, 6, datetime.datetime(2011, 5, 20, 0, 0), 'Rilská 3174/6', 'Prague', None, 'Czech Republic', '14300', Decimal('3.96'), 13, 'Fernanda', 'Ramos', None, 'Qe 7 Bloco G', 'Brasília', 'DF', 'Brazil', '71020-677', '+55 (61) 3363-5547', '+55 (61) 3363-7855', 'fernadaramos4@uol.com.br', 4),
#  (198, 6, datetime.datetime(2011, 5, 20, 0, 0), 'Rilská 3174/6', 'Prague', None, 'Czech Republic', '14300', Decimal('3.96'), 1, 'Luís', 'Gonçalves', 'Embraer - Empresa Brasileira de Aeronáutica S.A.', 'Av. Brigadeiro Faria Lima, 2170', 'São José dos Campos', 'SP', 'Brazil', '12227-000', '+55 (12) 3923-5555', '+55 (12) 3923-5566', 'luisg@embraer.com.br', 3),
#  (198, 6, datetime.datetime(2011, 5, 20, 0, 0), 'Rilská 3174/6', 'Prague', None, 'Czech Republic', '14300', Decimal('3.96'), 12, 'Roberto', 'Almeida', 'Riotur', 'Praça Pio X, 119', 'Rio de Janeiro', 'RJ', 'Brazil', '20040-020', '+55 (21) 2271-7000', '+55 (21) 2271-7070', 'roberto.almeida@riotur.gov.br', 3),
#  (199, 10, datetime.datetime(2011, 5, 21, 0, 0), 'Rua Dr. Falcão Filho, 155', 'São Paulo', 'SP', 'Brazil', '01007-010', Decimal('5.94'), 11, 'Alexandre', 'Rocha', 'Banco do Brasil S.A.', 'Av. Paulista, 2022', 'São Paulo', 'SP', 'Brazil', '01310-200', '+55 (11) 3055-3278', '+55 (11) 3055-8131', 'alero@uol.com.br', 5),
#  (199, 10, datetime.datetime(2011, 5, 21, 0, 0), 'Rua Dr. Falcão Filho, 155', 'São Paulo', 'SP', 'Brazil', '01007-010', Decimal('5.94'), 10, 'Eduardo', 'Martins', 'Woodstock Discos', 'Rua Dr. Falcão Filho, 155', 'São Paulo', 'SP', 'Brazil', '01007-010', '+55 (11) 3033-5446', '+55 (11) 3033-4564', 'eduardo@woodstock.com.br', 4),
#  (199, 10, datetime.datetime(2011, 5, 21, 0, 0), 'Rua Dr. Falcão Filho, 155', 'São Paulo', 'SP', 'Brazil', '01007-010', Decimal('5.94'), 13, 'Fernanda', 'Ramos', None, 'Qe 7 Bloco G', 'Brasília', 'DF', 'Brazil', '71020-677', '+55 (61) 3363-5547', '+55 (61) 3363-7855', 'fernadaramos4@uol.com.br', 4),
#  (199, 10, datetime.datetime(2011, 5, 21, 0, 0), 'Rua Dr. Falcão Filho, 155', 'São Paulo', 'SP', 'Brazil', '01007-010', Decimal('5.94'), 1, 'Luís', 'Gonçalves', 'Embraer - Empresa Brasileira de Aeronáutica S.A.', 'Av. Brigadeiro Faria Lima, 2170', 'São José dos Campos', 'SP', 'Brazil', '12227-000', '+55 (12) 3923-5555', '+55 (12) 3923-5566', 'luisg@embraer.com.br', 3),
#  (199, 10, datetime.datetime(2011, 5, 21, 0, 0), 'Rua Dr. Falcão Filho, 155', 'São Paulo', 'SP', 'Brazil', '01007-010', Decimal('5.94'), 12, 'Roberto', 'Almeida', 'Riotur', 'Praça Pio X, 119', 'Rio de Janeiro', 'RJ', 'Brazil', '20040-020', '+55 (21) 2271-7000', '+55 (21) 2271-7070', 'roberto.almeida@riotur.gov.br', 3),
#  (200, 16, datetime.datetime(2011, 5, 24, 0, 0), '1600 Amphitheatre Parkway', 'Mountain View', 'CA', 'USA', '94043-1351', Decimal('8.91'), 11, 'Alexandre', 'Rocha', 'Banco do Brasil S.A.', 'Av. Paulista, 2022', 'São Paulo', 'SP', 'Brazil', '01310-200', '+55 (11) 3055-3278', '+55 (11) 3055-8131', 'alero@uol.com.br', 5),
#  (200, 16, datetime.datetime(2011, 5, 24, 0, 0), '1600 Amphitheatre Parkway', 'Mountain View', 'CA', 'USA', '94043-1351', Decimal('8.91'), 10, 'Eduardo', 'Martins', 'Woodstock Discos', 'Rua Dr. Falcão Filho, 155', 'São Paulo', 'SP', 'Brazil', '01007-010', '+55 (11) 3033-5446', '+55 (11) 3033-4564', 'eduardo@woodstock.com.br', 4),
#  (200, 16, datetime.datetime(2011, 5, 24, 0, 0), '1600 Amphitheatre Parkway', 'Mountain View', 'CA', 'USA', '94043-1351', Decimal('8.91'), 13, 'Fernanda', 'Ramos', None, 'Qe 7 Bloco G', 'Brasília', 'DF', 'Brazil', '71020-677', '+55 (61) 3363-5547', '+55 (61) 3363-7855', 'fernadaramos4@uol.com.br', 4),
#  (200, 16, datetime.datetime(2011, 5, 24, 0, 0), '1600 Amphitheatre Parkway', 'Mountain View', 'CA', 'USA', '94043-1351', Decimal('8.91'), 1, 'Luís', 'Gonçalves', 'Embraer - Empresa Brasileira de Aeronáutica S.A.', 'Av. Brigadeiro Faria Lima, 2170', 'São José dos Campos', 'SP', 'Brazil', '12227-000', '+55 (12) 3923-5555', '+55 (12) 3923-5566', 'luisg@embraer.com.br', 3),
#  (200, 16, datetime.datetime(2011, 5, 24, 0, 0), '1600 Amphitheatre Parkway', 'Mountain View', 'CA', 'USA', '94043-1351', Decimal('8.91'), 12, 'Roberto', 'Almeida', 'Riotur', 'Praça Pio X, 119', 'Rio de Janeiro', 'RJ', 'Brazil', '20040-020', '+55 (21) 2271-7000', '+55 (21) 2271-7070', 'roberto.almeida@riotur.gov.br', 3),
#  ...]
